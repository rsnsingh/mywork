# %% [markdown]
# # DSCI 511: Data acquisition and pre-processing <br>Chapter 3: Acquiring Data from the Internet
#
# ## 3.1 APIs
# The entire infrastructure of the internet uses three basic ideas as building blocks: clients, servers, and requests. When you visit a website, your web browser is the _client_. In order to display the web page to you, your browser makes a _request_ to a remote _server_. The server then processes the request and sends back the page, which is essentially an HTML document. Your browser can interpret this document, which contains all kinds of information (including styling and presentation-related information and hyperlinks), and display it on your screen.
#
# ### 3.1.1 What is an API?
# An _Application Processing Interface_ (API) allows you to make a request to a remote server to obtain data instead of a web page. So instead of an HTML document, usually an API request will return some data in a format like, JSON, CSV, or XML. To review how to load data from these formats review Chapter 1.

# %% [markdown]
# ### 3.1.2 Accessing APIs
# When you access a web page, your browser makes a request to the remote server. The browser uses a URL address to send the request. Similarly, URLs are also used to send requests to APIs. Usually, constructing the URL needed to send the request is an important early step in working with APIs.
# #### 3.1.2.1 Making Requests and handling JSON responses
# When writing Python code to get data from APIs, we'll use the `requests` module to make these requests. The `requests.get()` method can be supplied with a URL, and returns a "response" object, which has a very convenient `.json()` method to process the response when it is a JSON file and return a dictionary (so we don't necessarily have to use the `json` module to de-serialize a request's text result. For example, we'll use the GitHub API to grab some data about a user.

# %%
import requests

# format: "https://api.github.com/user/USERNAME"
response = requests.get("https://api.github.com/users/jakerylandwilliams")

# json.loads(response.text)

response.json()
# Out:
# {'login': 'jakerylandwilliams',
#  'id': 4721029,
#  'node_id': 'MDQ6VXNlcjQ3MjEwMjk=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/4721029?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jakerylandwilliams',
#  'html_url': 'https://github.com/jakerylandwilliams',
#  'followers_url': 'https://api.github.com/users/jakerylandwilliams/followers',
#  'following_url': 'https://api.github.com/users/jakerylandwilliams/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jakerylandwilliams/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jakerylandwilliams/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jakerylandwilliams/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jakerylandwilliams/orgs',
#  'repos_url': 'https://api.github.com/users/jakerylandwilliams/repos',
#  'events_url': 'https://api.github.com/users/jakerylandwilliams/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jakerylandwilliams/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Jake Williams',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 5,
#  'public_gists': 0,
#  'followers': 37,
#  'following': 4,
#  'created_at': '2013-06-17T18:27:22Z',
#  'updated_at': '2022-09-21T13:06:27Z'}

# %% [markdown]
# GitHub's API doesn't require an "access token" to return this information about a user. There are thousands of public APIs available on the web that can help you get useful data, and many of them can be used as simply as this GitHub example.
# #### 3.1.2.2 A more local example of an API
# The Southeastern Pennsylvania Transportation Authority (SEPTA) [makes a few APIs available](http://www3.septa.org/hackathon/). Some of these APIs can be used to access realtime data about SEPTA transit (trains, buses, trolleys). For example, we can request data about the next trains to arrive at a given station.

# %%
# format: "http://www3.septa.org/hackathon/Arrivals/*STATION_NAME*/*NUMBER_OF_TRAINS*"
arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/30th Street Station/2")

arrivals_dict = arrivals_response.json()
arrivals_dict
# Out:
# {'30th Street Station Departures: October 14, 2022, 5:52 am': [{'Northbound': [{'direction': 'N',
#      'path': 'R4N',
#      'train_id': '404',
#      'origin': 'Airport Terminal E-F',
#      'destination': 'Warminster',
#      'line': 'Warminster',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Penn Medical Station',
#      'sched_time': '2022-10-14 05:59:01.000',
#      'depart_time': '2022-10-14 06:00:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R3N',
#      'train_id': '302',
#      'origin': 'Media',
#      'destination': 'West Trenton',
#      'line': 'Media/Wawa',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Gladstone',
#      'sched_time': '2022-10-14 06:09:01.000',
#      'depart_time': '2022-10-14 06:10:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]},
#   {'Southbound': [{'direction': 'S',
#      'path': 'R4S',
#      'train_id': '407',
#      'origin': 'Suburban Station',
#      'destination': 'Airport',
#      'line': 'Airport',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Suburban Station',
#      'sched_time': '2022-10-14 05:58:01.000',
#      'depart_time': '2022-10-14 05:59:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R8/2S',
#      'train_id': '8215',
#      'origin': 'Olney',
#      'destination': 'Newark',
#      'line': 'Fox Chase',
#      'status': '2 min',
#      'service_type': 'LTD',
#      'next_station': 'Olney',
#      'sched_time': '2022-10-14 06:18:01.000',
#      'depart_time': '2022-10-14 06:19:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]}]}

# %% [markdown]
# #### 3.1.2.3 Exercise: processing a JSON response
# Make a request to the SEPTA Arrivals API to get data on the next 10 trains to arrive at Suburban Station. Store this JSON-format data into a dictionary. Inspect the dictionary structure. Then, write code to create a list containing 10 dictionaries, one for each train. These new dictionaries should look like this:

# %%
from pprint import pprint
# example of train dictionary format
train_dict = {
    'direction': 'S',
     'line': 'Media/Elwyn',
     'sched_time': '2018-08-22 17:31:01.000',
     'status': 'On Time',
     'track': '6'
}

pprint(train_dict)
# Out:
# {'direction': 'S',
#  'line': 'Media/Elwyn',
#  'sched_time': '2018-08-22 17:31:01.000',
#  'status': 'On Time',
#  'track': '6'}

# %%
# code goes here

# arrivals_response =
# arrivals_dict =

# trains = []

# for station in arrivals_dict.values():
#    
from pprint import pprint
# example of train dictionary format
train_dict = {
    'direction': 'S',
     'line': 'Media/Elwyn',
     'sched_time': '2018-08-22 17:31:01.000',
     'status': 'On Time',
     'track': '6'
}

pprint(train_dict)
# format: "http://www3.septa.org/hackathon/Arrivals/*STATION_NAME*/*NUMBER_OF_TRAINS*"
arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/Suburban Station/1")
#arrivals_response
arrivals_dict = arrivals_response.json()
arrivals_dict

data = response.json()
top_keys = list(data.keys())
# pprint(data[top_keys[0]][0]["Northbound"])

train_keys = ['direction', 'line', 'sched_time', 'status', 'track']

trains = []
for timestamp in data: ## timestamp is the sole key at the top level of response
    for outbound_direction in data[timestamp]: ## each track direction gets its own dictionary
        for direction in outbound_direction:
            for train in outbound_direction[direction]:
                trains.append({
                    train_key: train[train_key]
                    for train_key in train_keys
                })
print(len(trains))
pprint(trains)
# Out:
# {'direction': 'S',
#  'line': 'Media/Elwyn',
#  'sched_time': '2018-08-22 17:31:01.000',
#  'status': 'On Time',
#  'track': '6'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 27
#      25 arrivals_dict
#      26 list1 = []
# ---> 27 print(arrivals_dict[0][0])
#
# KeyError: 0

# %% [markdown]
# #### 3.1.2.4 Open geo-location data
# Geolocation data can also be found in JSON format. The [OpenStreetMap (OSM) API](https://wiki.openstreetmap.org/wiki/Main_Page) can be used to request geographic data. Usually, map data is stored in the form of polygons, shapes with vertices consisting of latitude-longitude points. For example, we can obtain the polygon for Philadelphia from OSM like this:

# %%
response = requests.get("https://nominatim.openstreetmap.org/search.php?q=Philadelphia+Pennsylvania&polygon_geojson=1&format=json")

pprint(response.json())
# Out:
# [{'boundingbox': ['39.867005', '40.1379593', '-75.2802977', '-74.9558314'],
#   'class': 'place',
#   'display_name': 'Philadelphia, Philadelphia County, Pennsylvania, USA',
#   'geojson': {'coordinates': [[[-75.2802977, 39.9750019],
#                                [-75.2802246, 39.9748885],
#                                [-75.280192, 39.974835],
#                                [-75.28013, 39.974735],
#                                [-75.280085, 39.974624],
#                                [-75.280044, 39.97454],
#                                [-75.280027, 39.974502],
#                                [-75.279955, 39.974424],
#                                [-75.279805, 39.97432],
#                                [-75.2796, 39.974185],
#                                [-75.279465, 39.974122],
#                                [-75.279359, 39.974072],
#                                [-75.279242, 39.974031],
#                                [-75.27917, 39.973986],
#                                [-75.279123, 39.973913],
#                                [-75.279109, 39.973812],
#                                [-75.279081, 39.973691],
#                                [-75.279046, 39.973618],
#                                [-75.278998, 39.973526],
#                                [-75.278971, 39.973446],
#                                [-75.278952, 39.973359],
#                                [-75.278916, 39.973315],
#                                [-75.278859, 39.973247],
#                                [-75.27883, 39.973162],
#                                [-75.27881, 39.973051],
#                                [-75.278795, 39.97295],
#                                [-75.278784, 39.972841],
#                                [-75.27878, 39.972745],
#                                [-75.278777, 39.972692],
#                                [-75.278759, 39.972634],
#                                [-75.278724, 39.97253],
#                                [-75.278697, 39.972414],
#                                [-75.278657, 39.972332],
#                                [-75.278609, 39.972263],
#                                [-75.278537, 39.972185],
#                                [-75.278449, 39.972106],
#                                [-75.278352, 39.972013],
#                                [-75.278297, 39.971928],
#                                [-75.278018, 39.971751],
#                                [-75.277967, 39.971714],
#                                [-75.277886, 39.971693],
#                                [-75.277765, 39.971678],
#                                [-75.277676, 39.971659],
#                                [-75.277641, 39.971643],
#                                [-75.277591, 39.971615],
#                                [-75.277553, 39.971583],
#                                [-75.277529, 39.971555],
#                                [-75.277513, 39.971518],
#                                [-75.277505, 39.971487],
#                                [-75.277503, 39.971452],
#                                [-75.277509, 39.971424],
#                                [-75.277523, 39.971401],
#                                [-75.277551, 39.971386],
#                                [-75.277596, 39.971377],
#                                [-75.277646, 39.971362],
#                                [-75.277688, 39.971345],
#                                [-75.277713, 39.971321],
#                                [-75.277704, 39.971284],
#                                [-75.277687, 39.971247],
#                                [-75.277656, 39.971209],
#                                [-75.277611, 39.971175],
#                                [-75.277576, 39.97115],
#                                [-75.27754, 39.971127],
#                                [-75.277491, 39.97111],
#                                [-75.277421, 39.971097],
#                                [-75.277338, 39.971083],
#                                [-75.277266, 39.971082],
#                                [-75.277198, 39.971082],
#                                [-75.277136, 39.971089],
#                                [-75.277073, 39.971105],
#                                [-75.276896, 39.971175],
#                                [-75.276825, 39.971215],
#                                [-75.27676, 39.971244],
#                                [-75.276689, 39.971253],
#                                [-75.276583, 39.971262],
#                                [-75.276524, 39.971224],
#                                [-75.276485, 39.971178],
#                                [-75.276471, 39.971135],
#                                [-75.276528, 39.971095],
#                                [-75.276587, 39.971056],
#                                [-75.276636, 39.971016],
#                                [-75.276662, 39.970983],
#                                [-75.276674, 39.970945],
#                                [-75.276667, 39.970907],
#                                [-75.276656, 39.970862],
#                                [-75.27664, 39.970828],
#                                [-75.276611, 39.970776],
#                                [-75.276553, 39.970672],
#                                [-75.276508, 39.97059],
#                                [-75.276467, 39.97052],
#                                [-75.276438, 39.970468],
#                                [-75.276411, 39.970416],
#                                [-75.27637, 39.970388],
#                                [-75.276302, 39.970351],
#                                [-75.276277, 39.970342],
#                                [-75.276245, 39.97033],
#                                [-75.276186, 39.970324],
#                                [-75.276005, 39.970312],
#                                [-75.275819, 39.97031],
#                                [-75.275705, 39.970293],
#                                [-75.275652, 39.970259],
#                                [-75.275606, 39.970211],
#                                [-75.275567, 39.970125],
#                                [-75.275494, 39.969929],
#                                [-75.275456, 39.969778],
#                                [-75.275394, 39.969575],
#                                [-75.275362, 39.969503],
#                                [-75.27532, 39.969411],
#                                [-75.275266, 39.969364],
#                                [-75.275197, 39.969325],
#                                [-75.275084, 39.969297],
#                                [-75.275027, 39.969289],
#                                [-75.274889, 39.969287],
#                                [-75.274808, 39.969293],
#                                [-75.274488, 39.96931],
#                                [-75.274326, 39.969316],
#                                [-75.27415, 39.969317],
#                                [-75.274012, 39.969315],
#                                [-75.273912, 39.96931],
#                                [-75.27381, 39.969297],
#                                [-75.273681, 39.969287],
#                                [-75.273569, 39.969278],
#                                [-75.273492, 39.969276],
#                                [-75.273415, 39.969281],
#                                [-75.27328, 39.969294],
#                                [-75.273185, 39.969305],
#                                [-75.273054, 39.969305],
#                                [-75.272957, 39.969293],
#                                [-75.272815, 39.969244],
#                                [-75.272726, 39.969217],
#                                [-75.272625, 39.969178],
#                                [-75.272505, 39.969131],
#                                [-75.272344, 39.969094],
#                                [-75.272196, 39.969047],
#                                [-75.272086, 39.969011],
#                                [-75.272024, 39.968985],
#                                [-75.271985, 39.968944],
#                                [-75.271922, 39.968859],
#                                [-75.271863, 39.968805],
#                                [-75.271802, 39.968756],
#                                [-75.271698, 39.968729],
#                                [-75.27159, 39.968715],
#                                [-75.271491, 39.968709],
#                                [-75.271407, 39.968704],
#                                [-75.271327, 39.968691],
#                                [-75.271241, 39.968663],
#                                [-75.271168, 39.968633],
#                                [-75.271109, 39.968619],
#                                [-75.271043, 39.968609],
#                                [-75.270986, 39.968603],
#                                [-75.270913, 39.968619],
#                                [-75.270838, 39.968644],
#                                [-75.270773, 39.968663],
#                                [-75.270718, 39.968671],
#                                [-75.270651, 39.968675],
#                                [-75.270598, 39.96866],
#                                [-75.27057, 39.968638],
#                                [-75.270522, 39.968602],
#                                [-75.270501, 39.968585],
#                                [-75.270447, 39.968528],
#                                [-75.270422, 39.968479],
#                                [-75.270413, 39.968428],
#                                [-75.270402, 39.968357],
#                                [-75.270388, 39.968322],
#                                [-75.270297, 39.968184],
#                                [-75.270192, 39.967977],
#                                [-75.27014, 39.967872],
#                                [-75.270073, 39.967729],
#                                [-75.270054, 39.967653],
#                                [-75.27003, 39.967552],
#                                [-75.270002, 39.967479],
#                                [-75.269961, 39.967425],
#                                [-75.269919, 39.96738],
#                                [-75.269857, 39.967344],
#                                [-75.269801, 39.967326],
#                                [-75.269741, 39.967315],
#                                [-75.26967, 39.967317],
#                                [-75.269614, 39.967331],
#                                [-75.269548, 39.967355],
#                                [-75.269498, 39.967375],
#                                [-75.269445, 39.967388],
#                                [-75.269357, 39.967402],
#                                [-75.269272, 39.967391],
#                                [-75.269206, 39.967381],
#                                [-75.269157, 39.967374],
#                                [-75.269125, 39.967361],
#                                [-75.26908, 39.96733],
#                                [-75.269044, 39.967285],
#                                [-75.269016, 39.967235],
#                                [-75.268916, 39.967041],
#                                [-75.268846, 39.966946],
#                                [-75.268773, 39.96686],
#                                [-75.268701, 39.966796],
#                                [-75.268568, 39.966691],
#                                [-75.268513, 39.966651],
#                                [-75.268461, 39.966618],
#                                [-75.268393, 39.966589],
#                                [-75.268129, 39.966491],
#                                [-75.267909, 39.9664],
#                                [-75.267818, 39.966359],
#                                [-75.267779, 39.966341],
#                                [-75.26767, 39.966298],
#                                [-75.267598, 39.966273],
#                                [-75.267538, 39.966272],
#                                [-75.26753, 39.96627],
#                                [-75.267475, 39.96626],
#                                [-75.267386, 39.966215],
#                                [-75.267245, 39.966117],
#                                [-75.267214, 39.966092],
#                                [-75.267138, 39.966062],
#                                [-75.2671, 39.96605],
#                                [-75.267024, 39.966025],
#                                [-75.266909, 39.966008],
#                                [-75.266795, 39.966009],
#                                [-75.266707, 39.966021],
#                                [-75.266545, 39.966021],
#                                [-75.266395, 39.966018],
#                                [-75.266313, 39.966004],
#                                [-75.266193, 39.965968],
#                                [-75.266062, 39.96593],
#                                [-75.266048, 39.965926],
#                                [-75.265921, 39.96586],
#                                [-75.265858, 39.965791],
#                                [-75.265806, 39.965716],
#                                [-75.265744, 39.965626],
#                                [-75.265656, 39.965526],
#                                [-75.265598, 39.965448],
#                                [-75.265566, 39.965404],
#                                [-75.265528, 39.96535],
#                                [-75.265448, 39.965257],
#                                [-75.265388, 39.965224],
#                                [-75.265252, 39.965207],
#                                [-75.265058, 39.965192],
#                                [-75.264918, 39.965189],
#                                [-75.264758, 39.965184],
#                                [-75.264644, 39.965179],
#                                [-75.264553, 39.965181],
#                                [-75.264496, 39.965195],
#                                [-75.264373, 39.965242],
#                                [-75.264242, 39.965312],
#                                [-75.264131, 39.965373],
#                                [-75.264056, 39.965421],
#                                [-75.264016, 39.965457],
#                                [-75.26399, 39.965491],
#                                [-75.263928, 39.965529],
#                                [-75.263855, 39.965556],
#                                [-75.26377, 39.965596],
#                                [-75.263696, 39.965614],
#                                [-75.263614, 39.965621],
#                                [-75.26353, 39.965605],
#                                [-75.263467, 39.965577],
#                                [-75.263383, 39.965545],
#                                [-75.263307, 39.965505],
#                                [-75.263251, 39.965474],
#                                [-75.263195, 39.965457],
#                                [-75.263144, 39.965459],
#                                [-75.263092, 39.965486],
#                                [-75.263028, 39.965531],
#                                [-75.262961, 39.965579],
#                                [-75.262919, 39.965609],
#                                [-75.262836, 39.965639],
#                                [-75.262766, 39.965647],
#                                [-75.262679, 39.965638],
#                                [-75.262618, 39.965626],
#                                [-75.262559, 39.965617],
#                                [-75.262512, 39.965611],
#                                [-75.262457, 39.965633],
#                                [-75.262422, 39.965676],
#                                [-75.262382, 39.965739],
#                                [-75.262342, 39.965784],
#                                [-75.262273, 39.965851],
#                                [-75.262265, 39.965858],
#                                [-75.262242, 39.96588],
#                                [-75.262169, 39.965934],
#                                [-75.262153, 39.96595],
#                                [-75.262138, 39.965965],
#                                [-75.262116, 39.966006],
#                                [-75.262104, 39.966054],
#                                [-75.262093, 39.966087],
#                                [-75.262013, 39.966135],
#                                [-75.261893, 39.966171],
#                                [-75.261811, 39.96619],
#                                [-75.261736, 39.966182],
#                                [-75.261661, 39.966159],
#                                [-75.261547, 39.966116],
#                                [-75.261479, 39.966076],
#                                [-75.261445, 39.966031],
#                                [-75.261386, 39.966001],
#                                [-75.261284, 39.965997],
#                                [-75.261215, 39.966026],
#                                [-75.261161, 39.966081],
#                                [-75.261115, 39.966136],
#                                [-75.261026, 39.966198],
#                                [-75.260932, 39.966242],
#                                [-75.260828, 39.96627],
#                                [-75.260751, 39.96628],
#                                [-75.260662, 39.966269],
#                                [-75.260584, 39.966273],
#                                [-75.2604549, 39.9662706],
#                                [-75.260309, 39.966257],
#                                [-75.260065, 39.966196],
#                                [-75.259909, 39.966115],
#                                [-75.259779, 39.966081],
#                                [-75.259649, 39.966041],
#                                [-75.259551, 39.96601],
#                                [-75.25945, 39.965947],
#                                [-75.259428, 39.965892],
#                                [-75.259427, 39.965813],
#                                [-75.259423, 39.965761],
#                                [-75.2594, 39.965716],
#                                [-75.259333, 39.965698],
#                                [-75.259214, 39.965697],
#                                [-75.259078, 39.965692],
#                                [-75.258974, 39.965676],
#                                [-75.25889, 39.965648],
#                                [-75.258839, 39.965614],
#                                [-75.258797, 39.965571],
#                                [-75.258767, 39.965516],
#                                [-75.258738, 39.965447],
#                                [-75.258709, 39.965378],
#                                [-75.2587, 39.965324],
#                                [-75.258711, 39.96524],
#                                [-75.258715, 39.965059],
#                                [-75.258713, 39.964965],
#                                [-75.258706, 39.964903],
#                                [-75.258684, 39.964846],
#                                [-75.258637, 39.964766],
#                                [-75.25859, 39.964708],
#                                [-75.258547, 39.964618],
#                                [-75.25851, 39.964535],
#                                [-75.25847, 39.964484],
#                                [-75.258407, 39.964452],
#                                [-75.258339, 39.964449],
#                                [-75.258271, 39.964452],
#                                [-75.258189, 39.96445],
#                                [-75.25812, 39.964446],
#                                [-75.258058, 39.964428],
#                                [-75.258007, 39.964399],
#                                [-75.257976, 39.964377],
#                                [-75.257944, 39.964301],
#                                [-75.257944, 39.964236],
#                                [-75.257962, 39.964161],
#                                [-75.257991, 39.964095],
#                                [-75.258014, 39.963993],
#                                [-75.258012, 39.963854],
#                                [-75.258014, 39.963739],
#                                [-75.257994, 39.963677],
#                                [-75.257933, 39.963624],
#                                [-75.257858, 39.963594],
#                                [-75.257788, 39.963602],
#                                [-75.257705, 39.963631],
#                                [-75.257629, 39.963664],
#                                [-75.257543, 39.963705],
#                                [-75.257487, 39.963744],
#                                [-75.257418, 39.963766],
#                                [-75.2573049, 39.9637752],
#                                [-75.2572326, 39.9637761],
#                                [-75.2571266, 39.9637643],
#                                [-75.256981, 39.963688],
#                                [-75.2569, 39.963672],
#                                [-75.256816, 39.963677],
#                                [-75.256746, 39.963688],
#                                [-75.256686, 39.963719],
#                                [-75.256586, 39.963802],
#                                [-75.256383, 39.963974],
#                                [-75.256281, 39.964079],
#                                [-75.256193, 39.964155],
#                                [-75.256083, 39.964242],
#                                [-75.255966, 39.964312],
#                                [-75.255892, 39.964372],
#                                [-75.255852, 39.964437],
#                                [-75.255812, 39.964471],
#                                [-75.255686, 39.964546],
#                                [-75.255543, 39.964595],
#                                [-75.255409, 39.96463],
#                                [-75.255267, 39.964655],
#                                [-75.255112, 39.964691],
#                                [-75.254937, 39.964763],
#                                [-75.254738, 39.96485],
#                                [-75.254632, 39.964925],
#                                [-75.254543, 39.964992],
#                                [-75.254456, 39.965046],
#                                [-75.254381, 39.965127],
#                                [-75.254337, 39.965211],
#                                [-75.254302, 39.965273],
#                                [-75.254223, 39.965337],
#                                [-75.25414, 39.965404],
#                                [-75.254046, 39.965402],
#                                [-75.253936, 39.96539],
#                                [-75.253712, 39.965329],
#                                [-75.253582, 39.9653],
#                                [-75.253407, 39.965261],
#                                [-75.253314, 39.965226],
#                                [-75.2532156, 39.9651949],
#                                [-75.253077, 39.965214],
#                                [-75.252972, 39.965235],
#                                [-75.252843, 39.965244],
#                                [-75.252636, 39.965251],
#                                [-75.252334, 39.96528],
#                                [-75.252094, 39.965305],
#                                [-75.251923, 39.965318],
#                                [-75.251811, 39.96533],
#                                [-75.251707, 39.965346],
#                                [-75.251603, 39.965356],
#                                [-75.251496, 39.965337],
#                                [-75.251427, 39.965302],
#                                [-75.251368, 39.965249],
#                                [-75.251353, 39.965219],
#                                [-75.251341, 39.965192],
#                                [-75.251336, 39.965138],
#                                [-75.251342, 39.965072],
#                                [-75.251283, 39.965003],
#                                [-75.251201, 39.964912],
#                                [-75.2511683, 39.9648942],
#                                [-75.251102, 39.964858],
#                                [-75.2510368, 39.9648333],
#                                [-75.250913, 39.964837],
#                                [-75.250757, 39.964879],
#                                [-75.250606, 39.964948],
#                                [-75.2504297, 39.9650246],
#                                [-75.250313, 39.965069],
#                                [-75.250221, 39.965076],
#                                [-75.250133, 39.965067],
#                                [-75.2500501, 39.9650395],
#                                [-75.24999, 39.965001],
#                                [-75.249912, 39.964947],
#                                [-75.249848, 39.964908],
#                                [-75.2497449, 39.9648582],
#                                [-75.249465, 39.964721],
#                                [-75.248967, 39.964494],
#                                [-75.248615, 39.964352],
#                                [-75.248056, 39.964074],
#                                [-75.247903, 39.963979],
#                                [-75.247778, 39.963876],
#                                [-75.247685, 39.963777],
#                                [-75.247564, 39.963638],
#                                [-75.247479, 39.963528],
#                                [-75.247434, 39.963417],
#                                [-75.247405, 39.963327],
#                                [-75.247399, 39.963249],
#                                [-75.247418, 39.963191],
#                                [-75.247489, 39.963119],
#                                [-75.247604, 39.962992],
#                                [-75.247642, 39.96295],
#                                [-75.247653, 39.9628242],
#                                [-75.2476642, 39.9627501],
#                                [-75.247681, 39.96268],
#                                [-75.2477355, 39.9625573],
#                                [-75.2477733, 39.9622794],
#                                [-75.2476982, 39.9621627],
#                                [-75.2477053, 39.9620216],
#                                [-75.2477218, 39.9618771],
#                                [-75.2478163, 39.9616797],
#                                [-75.2478248, 39.9615021],
#                                [-75.2478248, 39.9613442],
#                                [-75.2478592, 39.9612126],
#                                [-75.2478935, 39.9610745],
#                                [-75.2479708, 39.9609429],
#                                [-75.2481252, 39.9607982],
#                                [-75.2482282, 39.9606469],
#                                [-75.2482969, 39.9605416],
#                                [-75.2483398, 39.9604298],
#                                [-75.2485115, 39.9602784],
#                                [-75.2486316, 39.9602061],
#                                [-75.2488033, 39.9601074],
#                                [-75.2490351, 39.959989],
#                                [-75.2491724, 39.9598903],
#                                [-75.2493011, 39.9597916],
#                                [-75.2494299, 39.9597061],
#                                [-75.249593, 39.9596271],
#                                [-75.2498504, 39.9595679],
#                                [-75.2500307, 39.959489],
#                                [-75.2501337, 39.9594429],
#                                [-75.2502796, 39.9593837],
#                                [-75.2504856, 39.9593048],
#                                [-75.2506058, 39.9592258],
#                                [-75.2507517, 39.9591337],
#                                [-75.2508461, 39.9590679],
#                                [-75.250889, 39.9589692],
#                                [-75.2508976, 39.9588442],
#                                [-75.2508976, 39.9586864],
#                                [-75.2508461, 39.9585482],
#                                [-75.250786, 39.9584561],
#                                [-75.2507002, 39.9583377],
#                                [-75.2505886, 39.9582456],
#                                [-75.2505285, 39.9581798],
#                                [-75.2504427, 39.9580745],
#                                [-75.2503568, 39.9579363],
#                                [-75.2502281, 39.9578113],
#                                [-75.250168, 39.9577127],
#                                [-75.2501165, 39.9576469],
#                                [-75.2499964, 39.9575811],
#                                [-75.2498934, 39.9575153],
#                                [-75.2497474, 39.9574298],
#                                [-75.2495844, 39.9573705],
#                                [-75.249344, 39.9571403],
#                                [-75.2492325, 39.9570547],
#                                [-75.2491295, 39.9570218],
#                                [-75.2490007, 39.9569758],
#                                [-75.2489149, 39.9568968],
#                                [-75.2489149, 39.9568179],
#                                [-75.2488977, 39.9567258],
#                                [-75.2488977, 39.9566139],
#                                [-75.2489063, 39.9565153],
#                                [-75.2489664, 39.9564297],
#                                [-75.2490866, 39.9563574],
#                                [-75.2492067, 39.9562192],
#                                [-75.2492325, 39.9561337],
#                                [-75.2492754, 39.956035],
#                                [-75.249241, 39.9559165],
#                                [-75.2492214, 39.9558213],
#                                [-75.2492005, 39.9557385],
#                                [-75.2492083, 39.9555816],
#                                [-75.2492558, 39.9554855],
#                                [-75.249346, 39.955385],
#                                [-75.249449, 39.9552848],
#                                [-75.2495153, 39.9552092],
#                                [-75.2495804, 39.9551463],
#                                [-75.2496187, 39.9550941],
#                                [-75.2496359, 39.9550415],
#                                [-75.2496702, 39.954956],
#                                [-75.2497045, 39.9548441],
#                                [-75.2497277, 39.9547227],
#                                [-75.249771, 39.9546087],
#                                [-75.2498196, 39.954507],
#                                [-75.2498762, 39.9543901],
#                                [-75.2499964, 39.9542849],
#                                [-75.250065, 39.954173],
#                                [-75.2501594, 39.9540612],
#                                [-75.2502538, 39.9539691],
#                                [-75.2503483, 39.9538769],
#                                [-75.250477, 39.9537651],
#                                [-75.2506573, 39.9536072],
#                                [-75.2507603, 39.9535019],
#                                [-75.2508632, 39.9533703],
#                                [-75.2509748, 39.9532519],
#                                [-75.251095, 39.9531203],
#                                [-75.2511207, 39.9530019],
#                                [-75.251095, 39.9528703],
#                                [-75.2510864, 39.9527782],
#                                [-75.2511207, 39.9526795],
#                                [-75.2512152, 39.9526137],
#                                [-75.251301, 39.9525413],
#                                [-75.251404, 39.9523571],
#                                [-75.2514726, 39.9522321],
#                                [-75.2515585, 39.9521202],
#                                [-75.2515928, 39.9520018],
#                                [-75.2516558, 39.9518008],
#                                [-75.2516404, 39.9516675],
#                                [-75.2516168, 39.9514882],
#                                [-75.2515701, 39.9513384],
#                                [-75.2515387, 39.9512581],
#                                [-75.2515089, 39.951209],
#                                [-75.2514471, 39.951159],
#                                [-75.2513696, 39.9511069],
#                                [-75.2513182, 39.951028],
#                                [-75.2512323, 39.950949],
#                                [-75.2511551, 39.950824],
#                                [-75.2511036, 39.9507253],
#                                [-75.251095, 39.9506332],
#                                [-75.2511207, 39.9505542],
#                                [-75.2511551, 39.9504292],
#                                [-75.2511894, 39.9503042],
#                                [-75.2512237, 39.9502252],
#                                [-75.2512838, 39.95012],
#                                [-75.2513611, 39.9499752],
#                                [-75.2514126, 39.9498831],
#                                [-75.2514726, 39.9497976],
#                                [-75.251507, 39.949712],
#                                [-75.2515327, 39.9496133],
#                                [-75.2515842, 39.949508],
#                                [-75.2515928, 39.9494093],
#                                [-75.2515413, 39.9492778],
#                                [-75.2514898, 39.9491791],
#                                [-75.2513954, 39.9490475],
#                                [-75.2513182, 39.9489619],
#                                [-75.2512323, 39.9488369],
#                                [-75.2511808, 39.9487579],
#                                [-75.2510692, 39.948679],
#                                [-75.2509662, 39.9485737],
#                                [-75.2508375, 39.9484684],
#                                [-75.2507251, 39.9483687],
#                                [-75.2505628, 39.9483171],
#                                [-75.2504169, 39.9482052],
#                                [-75.2503654, 39.9480934],
#                                [-75.2503225, 39.9479091],
#                                [-75.2502882, 39.9477709],
#                                [-75.2502453, 39.9476328],
#                                [-75.2502538, 39.9475143],
#                                [-75.2502453, 39.9474288],
#                                [-75.2501938, 39.9473367],
#                                [-75.2501165, 39.947238],
#                                [-75.2500736, 39.9471129],
#                                [-75.2500393, 39.9469616],
#                                [-75.2499964, 39.9467181],
#                                [-75.2499191, 39.9466523],
#                                [-75.2498075, 39.9465799],
#                                [-75.2496187, 39.946501],
#                                [-75.24949, 39.9464023],
#                                [-75.2493526, 39.9463167],
#                                [-75.2492239, 39.9461983],
#                                [-75.2489321, 39.9459482],
#                                [-75.248769, 39.9457772],
#                                [-75.2486316, 39.945685],
#                                [-75.24846, 39.9455271],
#                                [-75.2483227, 39.9454481],
#                                [-75.2482969, 39.9453363],
#                                [-75.2482712, 39.9452178],
#                                [-75.2482025, 39.9451191],
#                                [-75.2481167, 39.9450007],
#                                [-75.248048, 39.9449151],
#                                [-75.2479364, 39.9448428],
#                                [-75.2477991, 39.9447375],
#                                [-75.2477047, 39.9446453],
#                                [-75.2476446, 39.9445598],
#                                [-75.2475711, 39.944515],
#                                [-75.2475022, 39.944448],
#                                [-75.2474492, 39.9444031],
#                                [-75.2474236, 39.9443551],
#                                [-75.2474107, 39.9443196],
#                                [-75.2474022, 39.9442469],
#                                [-75.247377, 39.944138],
#                                [-75.2473365, 39.9440586],
#                                [-75.2472755, 39.9439873],
#                                [-75.2472201, 39.9438996],
#                                [-75.2471856, 39.9438238],
#                                [-75.2471073, 39.9435924],
#                                [-75.2470781, 39.9435004],
#                                [-75.247034, 39.9434178],
#                                [-75.2469236, 39.9432766],
#                                [-75.2469236, 39.9431713],
#                                [-75.246915, 39.9430858],
#                                [-75.2468378, 39.9429871],
#                                [-75.2467863, 39.942895],
#                                [-75.246709, 39.9428292],
#                                [-75.2465631, 39.9427436],
#                                [-75.2464516, 39.9427041],
#                                [-75.2463571, 39.9426581],
#                                [-75.246134, 39.9426186],
#                                [-75.2459194, 39.942612],
#                                [-75.2457477, 39.9426252],
#                                [-75.2454902, 39.9426186],
#                                [-75.2451727, 39.9426054],
#                                [-75.2448723, 39.9426054],
#                                [-75.2447006, 39.9425923],
#                                [-75.2445461, 39.9425791],
#                                [-75.2444088, 39.9425659],
#                                [-75.2441942, 39.9425396],
#                                [-75.2439968, 39.9425199],
#                                [-75.2437736, 39.9424935],
#                                [-75.2435934, 39.9424606],
#                                [-75.243499, 39.9424212],
#                                [-75.2433273, 39.9423356],
#                                [-75.2431814, 39.942329],
#                                [-75.242984, 39.9423225],
#                                [-75.2427866, 39.9423159],
#                                [-75.2426063, 39.9423027],
#                                [-75.2424175, 39.9422961],
#                                [-75.2421686, 39.942283],
#                                [-75.2419626, 39.9422698],
#                                [-75.2416536, 39.9422566],
#                                [-75.2414648, 39.9422698],
#                                [-75.241233, 39.9422632],
#                                [-75.2410528, 39.9422632],
#                                [-75.2409069, 39.9422435],
#                                [-75.2407352, 39.9422237],
#                                [-75.2404692, 39.9422172],
#                                [-75.240349, 39.9421908],
#                                [-75.240246, 39.9421579],
#                                [-75.2401001, 39.9420395],
#                                [-75.24004, 39.9419408],
#                                [-75.2399713, 39.9418421],
#                                [-75.2399198, 39.9417434],
#                                [-75.2398855, 39.9416841],
#                                [-75.2397911, 39.9415788],
#                                [-75.239731, 39.9415065],
#                                [-75.2396795, 39.9414341],
#                                [-75.2396108, 39.9413419],
#                                [-75.2395508, 39.941263],
#                                [-75.239525, 39.941184],
#                                [-75.2394563, 39.9410721],
#                                [-75.2394134, 39.9409866],
#                                [-75.2394049, 39.9409274],
#                                [-75.2393877, 39.9408221],
#                                [-75.2393877, 39.9407234],
#                                [-75.2394306, 39.9406181],
#                                [-75.2394478, 39.9405194],
#                                [-75.2395508, 39.9404009],
#                                [-75.2396709, 39.9402759],
#                                [-75.2397997, 39.9401772],
#                                [-75.2399542, 39.9399797],
#                                [-75.2399971, 39.9398415],
#                                [-75.2400829, 39.9397362],
#                                [-75.2401687, 39.9396507],
#                                [-75.240246, 39.939552],
#                                [-75.2404091, 39.9394204],
#                                [-75.2405378, 39.9392953],
#                                [-75.2406065, 39.9392295],
#                                [-75.2406923, 39.9391374],
#                                [-75.2407352, 39.939065],
#                                [-75.2407781, 39.9389663],
#                                [-75.240761, 39.9388544],
#                                [-75.2407524, 39.9387689],
#                                [-75.2406923, 39.9386899],
#                                [-75.2406322, 39.9386175],
#                                [-75.2405206, 39.9385583],
#                                [-75.2404005, 39.9384464],
#                                [-75.2402975, 39.9383674],
#                                [-75.2401945, 39.938295],
#                                [-75.2400915, 39.9382555],
#                                [-75.2399713, 39.9381897],
#                                [-75.239834, 39.9381766],
#                                [-75.2395937, 39.9381568],
#                                [-75.2393705, 39.9381634],
#                                [-75.2392332, 39.9381502],
#                                [-75.2390873, 39.9381437],
#                                [-75.2389328, 39.9381437],
#                                [-75.2384779, 39.9381832],
#                                [-75.2382805, 39.9382029],
#                                [-75.238126, 39.9382095],
#                                [-75.2378427, 39.9382358],
#                                [-75.2377226, 39.9382621],
#                                [-75.2375423, 39.938295],
#                                [-75.2373363, 39.9383345],
#                                [-75.2371561, 39.9383608],
#                                [-75.2369501, 39.9384135],
#                                [-75.236684, 39.9384398],
#                                [-75.2365209, 39.938453],
#                                [-75.2362892, 39.9384464],
#                                [-75.2359716, 39.9384398],
#                                [-75.2357399, 39.9384069],
#                                [-75.2356369, 39.9383806],
#                                [-75.2354481, 39.9383279],
#                                [-75.2353107, 39.9383148],
#                                [-75.2351734, 39.9382621],
#                                [-75.235079, 39.9382095],
#                                [-75.2350189, 39.9380976],
#                                [-75.2349932, 39.9379923],
#                                [-75.2350017, 39.9379002],
#                                [-75.2350017, 39.937808],
#                                [-75.2350103, 39.9377159],
#                                [-75.2349932, 39.9376369],
#                                [-75.2349502, 39.9375382],
#                                [-75.2348816, 39.9374658],
#                                [-75.2348472, 39.9373803],
#                                [-75.2348301, 39.9373145],
#                                [-75.2348215, 39.9372026],
#                                [-75.2348472, 39.9370117],
#                                [-75.2348644, 39.9369262],
#                                [-75.2348387, 39.9368077],
#                                [-75.2348816, 39.9366958],
#                                [-75.2349417, 39.9365511],
#                                [-75.2350017, 39.9364326],
#                                [-75.2350275, 39.9363339],
#                                [-75.2350532, 39.9362417],
#                                [-75.2351133, 39.936143],
#                                [-75.2351734, 39.9360575],
#                                [-75.2352936, 39.9359785],
#                                [-75.235388, 39.9359258],
#                                [-75.2354996, 39.93586],
#                                [-75.2356111, 39.935814],
#                                [-75.2356798, 39.9357679],
#                                [-75.2357914, 39.9356889],
#                                [-75.2359201, 39.9356165],
#                                [-75.2360489, 39.9355507],
#                                [-75.2361175, 39.9354652],
#                                [-75.2362034, 39.9353993],
#                                [-75.2362806, 39.935327],
#                                [-75.2363579, 39.935248],
#                                [-75.2364094, 39.9351756],
#                                [-75.2364523, 39.9351098],
#                                [-75.2364952, 39.9350111],
#                                [-75.2365038, 39.9349189],
#                                [-75.2365124, 39.934807],
#                                [-75.2365381, 39.9347215],
#                                [-75.2365381, 39.9346228],
#                                [-75.2365639, 39.9345635],
#                                [-75.2365724, 39.9344714],
#                                [-75.2365896, 39.9343595],
#                                [-75.2366154, 39.9342739],
#                                [-75.2366154, 39.9341884],
#                                [-75.2366669, 39.9340897],
#                                [-75.2365553, 39.9337803],
#                                [-75.2366325, 39.9336092],
#                                [-75.2366754, 39.9334908],
#                                [-75.2367441, 39.933392],
#                                [-75.2368042, 39.9332867],
#                                [-75.23689, 39.9331617],
#                                [-75.2369501, 39.933063],
#                                [-75.2369844, 39.9329774],
#                                [-75.2370359, 39.9328919],
#                                [-75.2371389, 39.93278],
#                                [-75.2372248, 39.9327207],
#                                [-75.2373106, 39.9326483],
#                                [-75.2374307, 39.9325759],
#                                [-75.2375681, 39.9325365],
#                                [-75.2377569, 39.9325299],
#                                [-75.2378599, 39.9325299],
#                                [-75.2380316, 39.9325694],
#                                [-75.2380745, 39.9326286],
#                                [-75.2383234, 39.9326154],
#                                [-75.2384521, 39.9326549],
#                                [-75.238598, 39.9327076],
#                                [-75.2386753, 39.9327471],
#                                [-75.2388126, 39.9328063],
#                                [-75.2389671, 39.932905],
#                                [-75.2390959, 39.9329972],
#                                [-75.2391903, 39.9330696],
#                                [-75.2393362, 39.9331617],
#                                [-75.2394821, 39.9332078],
#                                [-75.2396366, 39.9332802],
#                                [-75.2397911, 39.9333328],
#                                [-75.2399113, 39.9333723],
#                                [-75.2400142, 39.9334118],
#                                [-75.240349, 39.9335961],
#                                [-75.2405121, 39.9336421],
#                                [-75.240658, 39.9336553],
#                                [-75.2409756, 39.933629],
#                                [-75.2411987, 39.9336092],
#                                [-75.2414047, 39.9335961],
#                                [-75.2415678, 39.9335566],
#                                [-75.2417051, 39.9335105],
#                                [-75.2419626, 39.9334513],
#                                [-75.2420914, 39.933392],
#                                [-75.2421686, 39.9333196],
#                                [-75.2422544, 39.9331946],
#                                [-75.2423403, 39.9330893],
#                                [-75.2423918, 39.9330037],
#                                [-75.2424604, 39.9328787],
#                                [-75.2425205, 39.9327997],
#                                [-75.2426321, 39.9326878],
#                                [-75.2427608, 39.932543],
#                                [-75.2427952, 39.9324641],
#                                [-75.2429497, 39.9323193],
#                                [-75.2429926, 39.9322271],
#                                [-75.2431042, 39.9321152],
#                                [-75.2432072, 39.931977],
#                                [-75.2433702, 39.9318586],
#                                [-75.2434217, 39.9317335],
#                                [-75.2434303, 39.9316085],
#                                [-75.2434475, 39.9314439],
#                                [-75.2435247, 39.9313452],
# ...
#                                [-75.237638, 40.031869],
#                                [-75.237152, 40.031614],
#                                [-75.235704, 40.030736],
#                                [-75.235019, 40.030232],
#                                [-75.234814, 40.030097],
#                                [-75.233923, 40.02949],
#                                [-75.232906, 40.028604],
#                                [-75.232585, 40.028389],
#                                [-75.232502, 40.028335],
#                                [-75.232473, 40.028314],
#                                [-75.232438, 40.028292],
#                                [-75.232407, 40.028271],
#                                [-75.232373, 40.028248],
#                                [-75.231702, 40.0278],
#                                [-75.231336, 40.027613],
#                                [-75.231249, 40.027568],
#                                [-75.231041, 40.027462],
#                                [-75.230949, 40.027416],
#                                [-75.230745, 40.027312],
#                                [-75.229678, 40.026793],
#                                [-75.228249, 40.026082],
#                                [-75.228216, 40.026066],
#                                [-75.228178, 40.026046],
#                                [-75.2281076, 40.0260097],
#                                [-75.228006, 40.025961],
#                                [-75.227952, 40.025934],
#                                [-75.226652, 40.025267],
#                                [-75.226513, 40.025197],
#                                [-75.226308, 40.025092],
#                                [-75.225191, 40.024459],
#                                [-75.223945, 40.023809],
#                                [-75.22367, 40.023633],
#                                [-75.223037, 40.023196],
#                                [-75.222205, 40.022542],
#                                [-75.221216, 40.022187],
#                                [-75.220498, 40.022026],
#                                [-75.219693, 40.02175],
#                                [-75.219583, 40.021713],
#                                [-75.219481, 40.021696],
#                                [-75.219331, 40.021671],
#                                [-75.218558, 40.021296],
#                                [-75.218488, 40.021258],
#                                [-75.217344, 40.020423],
#                                [-75.216255, 40.019507],
#                                [-75.21567, 40.018886],
#                                [-75.215424, 40.018626],
#                                [-75.214663, 40.017835],
#                                [-75.214644, 40.017815],
#                                [-75.213855, 40.016914],
#                                [-75.213462, 40.016561],
#                                [-75.213386, 40.016473],
#                                [-75.213135, 40.016182],
#                                [-75.21187, 40.014881],
#                                [-75.211038, 40.014207],
#                                [-75.211013, 40.01418],
#                                [-75.210192, 40.013826],
#                                [-75.208722, 40.013349],
#                                [-75.208008, 40.012997],
#                                [-75.207728, 40.012805],
#                                [-75.207628, 40.012736],
#                                [-75.207599, 40.012719],
#                                [-75.206405, 40.012002],
#                                [-75.206286, 40.011923],
#                                [-75.206792, 40.011512],
#                                [-75.206871, 40.011448],
#                                [-75.2069325, 40.0114004],
#                                [-75.206968, 40.011372],
#                                [-75.207192, 40.011188],
#                                [-75.2072804, 40.0111068],
#                                [-75.2073552, 40.010459],
#                                [-75.2098348, 40.0090677],
#                                [-75.2107421, 40.0085968],
#                                [-75.213273, 40.0073911],
#                                [-75.2137763, 40.0071659],
#                                [-75.215055, 40.0066035],
#                                [-75.2183557, 40.0050448],
#                                [-75.2184808, 40.004986],
#                                [-75.2187252, 40.0048713],
#                                [-75.2188738, 40.0048015],
#                                [-75.2192383, 40.0046304],
#                                [-75.2197201, 40.0044041],
#                                [-75.2198205, 40.004357],
#                                [-75.2205706, 40.0040045],
#                                [-75.2206928, 40.0039471],
#                                [-75.2208579, 40.0038695],
#                                [-75.2209935, 40.0038057],
#                                [-75.2211935, 40.0037117],
#                                [-75.2215868, 40.0035269],
#                                [-75.2221384, 40.0032676],
#                                [-75.22278, 40.002966],
#                                [-75.2230659, 40.0028316],
#                                [-75.2231392, 40.0027972],
#                                [-75.2232458, 40.002747],
#                                [-75.2235553, 40.0026016],
#                                [-75.2236334, 40.0025649],
#                                [-75.2237665, 40.0025026],
#                                [-75.224164, 40.0023167],
#                                [-75.224444, 40.0021858],
#                                [-75.2246975, 40.0020672],
#                                [-75.2256121, 40.0016395],
#                                [-75.2258835, 40.0015126],
#                                [-75.2260886, 40.0014193],
#                                [-75.2263109, 40.0013192],
#                                [-75.2264267, 40.001267],
#                                [-75.2283762, 40.0003293],
#                                [-75.2286667, 40.0001913],
#                                [-75.2287422, 40.0001555],
#                                [-75.2288061, 40.0001255],
#                                [-75.2288307, 40.000114],
#                                [-75.2291266, 39.9999753],
#                                [-75.229297, 39.9998954],
#                                [-75.2294612, 39.9998185],
#                                [-75.2294957, 39.9998024],
#                                [-75.2295759, 39.9997648],
#                                [-75.2296317, 39.9997386],
#                                [-75.2298399, 39.999641],
#                                [-75.2299342, 39.9995968],
#                                [-75.2301922, 39.9994759],
#                                [-75.2302196, 39.999463],
#                                [-75.230393, 39.9993818],
#                                [-75.2305034, 39.9993301],
#                                [-75.2307089, 39.9992337],
#                                [-75.2307907, 39.9991954],
#                                [-75.2308937, 39.9991471],
#                                [-75.2310073, 39.9990939],
#                                [-75.2312946, 39.9989593],
#                                [-75.2313551, 39.9989309],
#                                [-75.2317034, 39.9987676],
#                                [-75.2319529, 39.9986507],
#                                [-75.2320814, 39.9985905],
#                                [-75.2321604, 39.9985534],
#                                [-75.2323082, 39.9984841],
#                                [-75.2323395, 39.9984695],
#                                [-75.23245, 39.9984177],
#                                [-75.2325374, 39.9983767],
#                                [-75.2325646, 39.998364],
#                                [-75.2330761, 39.9981243],
#                                [-75.2332265, 39.9980538],
#                                [-75.2341826, 39.9976057],
#                                [-75.2343069, 39.9975474],
#                                [-75.2345954, 39.9974122],
#                                [-75.2351873, 39.9971348],
#                                [-75.2352829, 39.99709],
#                                [-75.2354053, 39.9970326],
#                                [-75.2359613, 39.996772],
#                                [-75.2361909, 39.9966642],
#                                [-75.2364033, 39.9965646],
#                                [-75.2365922, 39.996476],
#                                [-75.2371629, 39.9962081],
#                                [-75.2373554, 39.9961178],
#                                [-75.2376813, 39.9959649],
#                                [-75.2383741, 39.9956398],
#                                [-75.2389578, 39.9953659],
#                                [-75.2390241, 39.9953348],
#                                [-75.2394591, 39.9951306],
#                                [-75.2398632, 39.994941],
#                                [-75.2405759, 39.9946066],
#                                [-75.2410936, 39.9943636],
#                                [-75.2415315, 39.9941581],
#                                [-75.2416442, 39.9941052],
#                                [-75.2429808, 39.993478],
#                                [-75.2437775, 39.9931041],
#                                [-75.2444215, 39.9928019],
#                                [-75.244981, 39.9925393],
#                                [-75.2452013, 39.9924359],
#                                [-75.2456152, 39.9922417],
#                                [-75.2456831, 39.9922098],
#                                [-75.2457615, 39.992173],
#                                [-75.2461406, 39.9919951],
#                                [-75.2471286, 39.9915314],
#                                [-75.2479989, 39.991123],
#                                [-75.2486588, 39.9908133],
#                                [-75.249091, 39.9906105],
#                                [-75.249211, 39.9905542],
#                                [-75.2493062, 39.9905095],
#                                [-75.2495393, 39.9904001],
#                                [-75.2498433, 39.9902574],
#                                [-75.2501653, 39.9901063],
#                                [-75.2508207, 39.9897987],
#                                [-75.25092, 39.9897521],
#                                [-75.2509948, 39.989717],
#                                [-75.2511594, 39.9896397],
#                                [-75.2513851, 39.9895338],
#                                [-75.2514604, 39.9894985],
#                                [-75.251552, 39.9894555],
#                                [-75.2518995, 39.9892924],
#                                [-75.2530653, 39.9887453],
#                                [-75.2533625, 39.9886058],
#                                [-75.2538337, 39.9883842],
#                                [-75.2539906, 39.9883105],
#                                [-75.254166, 39.9882245],
#                                [-75.2547823, 39.9879373],
#                                [-75.2556982, 39.9875105],
#                                [-75.2560625, 39.9873407],
#                                [-75.256141, 39.9873011],
#                                [-75.2562098, 39.9872584],
#                                [-75.2565115, 39.9870358],
#                                [-75.2568291, 39.9868014],
#                                [-75.257306, 39.9864495],
#                                [-75.2581301, 39.9858415],
#                                [-75.2584576, 39.9855984],
#                                [-75.2585693, 39.9855155],
#                                [-75.2586827, 39.9854313],
#                                [-75.2587255, 39.9853995],
#                                [-75.2588059, 39.9853435],
#                                [-75.2588935, 39.9852894],
#                                [-75.2590647, 39.985195],
#                                [-75.2591995, 39.9851207],
#                                [-75.259496, 39.9849572],
#                                [-75.2602505, 39.9845412],
#                                [-75.2607249, 39.9842796],
#                                [-75.2608095, 39.984233],
#                                [-75.2613089, 39.9839577],
#                                [-75.2632595, 39.9828821],
#                                [-75.263458, 39.9827794],
#                                [-75.2637148, 39.9826586],
#                                [-75.2639178, 39.9825683],
#                                [-75.2640155, 39.9825249],
#                                [-75.2642755, 39.9824093],
#                                [-75.2643874, 39.9823595],
#                                [-75.2644971, 39.9823108],
#                                [-75.2647856, 39.9821825],
#                                [-75.2655202, 39.981856],
#                                [-75.2656027, 39.9818193],
#                                [-75.2662612, 39.9815266],
#                                [-75.2681096, 39.9807049],
#                                [-75.2685034, 39.9805298],
#                                [-75.2686106, 39.9804824],
#                                [-75.2691382, 39.9802492],
#                                [-75.2692581, 39.9801962],
#                                [-75.2694568, 39.9801073],
#                                [-75.2696655, 39.9800139],
#                                [-75.269732, 39.9799842],
#                                [-75.2699077, 39.9799055],
#                                [-75.2702082, 39.9797721],
#                                [-75.2706617, 39.9795703],
#                                [-75.2713415, 39.9792681],
#                                [-75.2715309, 39.9791839],
#                                [-75.2717188, 39.9791003],
#                                [-75.2719423, 39.979001],
#                                [-75.2722755, 39.9788528],
#                                [-75.2723598, 39.9788154],
#                                [-75.2726209, 39.9786993],
#                                [-75.2728376, 39.978603],
#                                [-75.2730377, 39.978514],
#                                [-75.2734536, 39.9783291],
#                                [-75.2735748, 39.9782753],
#                                [-75.2736619, 39.9782365],
#                                [-75.2739555, 39.978106],
#                                [-75.2741247, 39.9780308],
#                                [-75.2753017, 39.9775075],
#                                [-75.2759004, 39.9772414],
#                                [-75.2761523, 39.9771294],
#                                [-75.2764814, 39.9769753],
#                                [-75.2768054, 39.9768119],
#                                [-75.2776948, 39.9763438],
#                                [-75.2789674, 39.9756741],
#                                [-75.2796234, 39.9753288],
#                                [-75.2799089, 39.9751869],
#                                [-75.2802608, 39.97502],
#                                [-75.2802977, 39.9750019]]],
#               'type': 'Polygon'},
#   'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_boundary_administrative.p.20.png',
#   'importance': 0.654641846889805,
#   'lat': '40.0114538',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'https://osm.org/copyright',
#   'lon': '-75.1326504',
#   'osm_id': 417845,
#   'osm_type': 'relation',
#   'place_id': 198245929,
#   'type': 'administrative'},
#  {'boundingbox': ['40.1312188', '40.1313188', '-74.9675694', '-74.9674694'],
#   'class': 'highway',
#   'display_name': 'Bensalem, Pennsylvania Turnpike, Bensalem Township, Bucks '
#                   'County, Pennsylvania, 19053, USA',
#   'geojson': {'coordinates': [-74.9675194, 40.1312688], 'type': 'Point'},
#   'importance': 0.11100000000000002,
#   'lat': '40.1312688',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'https://osm.org/copyright',
#   'lon': '-74.9675194',
#   'osm_id': 493827960,
#   'osm_type': 'node',
#   'place_id': 4545148,
#   'type': 'motorway_junction'}]

# %% [markdown]
# ### 3.1.3 Working with CSV responses
# Sometimes API responses can be in CSV format, too. For example, the schedule data API for Center City regional arrivals by SEPTA returns CSVs. Since a CSV file is really just a text file, we can read the text from the response using a CSV reader. In the output below, showing the schedule data being displayed [here](http://www3.septa.org/ccstations/30th/) in CSV format, notice that the first line and the last two lines are not part of the table, rather messages and timestamps. Further, the CSV does not appear to have been written properly in the usual one-entry-per-line format. Rather, entries for trains on the same line are joined together. Irregularities like this are easy to miss, but can end up breaking your code.

# %%
import csv
# format: "http://www3.septa.org/ccstations/STATION/sched_data.csv", acceptable values for STATION are "me", "ss", and "30th"
schedule_response = requests.get("http://www3.septa.org/ccstations/30th/sched_data.csv")
schedule_text = schedule_response.text.strip().split("\n") # removing leading and trailing spaces and splitting lines
schedule_reader = csv.reader(schedule_text)
schedule = list(schedule_reader)
pprint(schedule)
# Out:
# [["EMG=' No Emg Message"],
#  ['R4S=04:29',
#   'Airport',
#   '6',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '449   ',
#   '<_NEXT_MSG>04:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9451  ',
#   '<_NEXT_MSG>05:29',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '453   ',
#   '<_NEXT_MSG>05:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9455  ',
#   ''],
#  ['R4N=04:27',
#   'Warminster',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '5444  ',
#   '<_NEXT_MSG>04:55',
#   'Warminster',
#   '5',
#   ' 1 LATE',
#   'EXP TO JENKINTOWN        ',
#   '3448  ',
#   '<_NEXT_MSG>05:30',
#   'Warminster',
#   '2',
#   'ON TIME',
#   'EXP TO JENKINTOWN        ',
#   '6448  ',
#   '<_NEXT_MSG>06:00',
#   'Glenside',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '452   ',
#   ''],
#  ['R2S=04:34',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9245  ',
#   '<_NEXT_MSG>04:54',
#   'Claymont',
#   '6',
#   ' 2 LATE',
#   'LOCAL                    ',
#   '5249  ',
#   '<_NEXT_MSG>05:14',
#   'Newark',
#   '6',
#   'ON TIME',
#   'EXP TO RIDLEY PARK LTD   ',
#   '9251  ',
#   '<_NEXT_MSG>05:19',
#   'Marcus Hook',
#   '6',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '5253  ',
#   ''],
#  ['R3N=04:22',
#   'West Trenton',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '2372  ',
#   '<_NEXT_MSG>04:42',
#   'West Trenton',
#   '1',
#   'ON TIME',
#   'EXP TO BETHAYRES         ',
#   '6374  ',
#   '<_NEXT_MSG>04:49',
#   'West Trenton',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '7376  ',
#   '<_NEXT_MSG>05:13',
#   'West Trenton',
#   '1',
#   'ON TIME',
#   'EXP TO BETHAYRES         ',
#   '6378  ',
#   ''],
#  ['R3S=04:30',
#   'Elwyn',
#   '6',
#   ' 2 LATE',
#   'LOCAL                    ',
#   '9359  ',
#   '<_NEXT_MSG>04:57',
#   'Elwyn',
#   '6',
#   'ON TIME',
#   'EXP TO PRIMOS            ',
#   '7363  ',
#   '<_NEXT_MSG>05:11',
#   'Elwyn',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '361   ',
#   '<_NEXT_MSG>05:26',
#   'Elwyn',
#   '6',
#   'ON TIME',
#   'EXP TO PRIMOS            ',
#   '9365  ',
#   ''],
#  ['R5N=04:38',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'EXP TO FT WASH           ',
#   '6572  ',
#   '<_NEXT_MSG>04:45',
#   'Lansdale',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '574   ',
#   '<_NEXT_MSG>05:06',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'EXP TO N WALES           ',
#   '6576  ',
#   '<_NEXT_MSG>05:12',
#   'Lansdale',
#   '1',
#   'ON TIME',
#   'EXP TO FT WASH           ',
#   '6596  ',
#   ''],
#  ['R5S=04:48',
#   'Thorndale',
#   '4',
#   'ON TIME',
#   'EXP TO BRYN MAWR         ',
#   '9553  ',
#   '<_NEXT_MSG>04:51',
#   'Bryn Mawr',
#   '4',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '2555  ',
#   '<_NEXT_MSG>05:09',
#   'Paoli',
#   '4',
#   'ON TIME',
#   'EXP TO BRYN MAWR         ',
#   '9559  ',
#   '<_NEXT_MSG>05:13',
#   'Thorndale',
#   '4',
#   'ON TIME',
#   'EXP TO PAOLI             ',
#   '9561  ',
#   ''],
#  ['R2N=04:24',
#   'Norristown',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '8246  ',
#   '<_NEXT_MSG>04:40',
#   'Norristown',
#   '2',
#   'ON TIME',
#   'EXP TO EAST FALLS        ',
#   '6248  ',
#   '<_NEXT_MSG>04:59',
#   'Norristown',
#   '2',
#   'ON TIME',
#   'EXP TO EAST FALLS        ',
#   '6250  ',
#   '<_NEXT_MSG>05:12',
#   'Norristown TC',
#   '2',
#   'ON TIME',
#   'EXP TO EAST FALLS        ',
#   '7250  ',
#   ''],
#  ['R0=04:41',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1081  ',
#   '<_NEXT_MSG>05:18',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1083  ',
#   '<_NEXT_MSG>05:58',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1085  ',
#   '<_NEXT_MSG>06:36',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1087  ',
#   ''],
#  ['R7N=04:32',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '6754  ',
#   '<_NEXT_MSG>05:04',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '6710  ',
#   '<_NEXT_MSG>05:30',
#   'Chestnut H East',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '4758  ',
#   '<_NEXT_MSG>05:42',
#   'Suburban Sta',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '1758  ',
#   ''],
#  ['R7S=04:38',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '743   ',
#   '<_NEXT_MSG>04:54',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'EXP TO HOLMESBURG        ',
#   '9745  ',
#   '<_NEXT_MSG>05:15',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'EXP TO TORRESDALE        ',
#   '9747  ',
#   '<_NEXT_MSG>05:24',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'EXP EDDINGTON TO TRENTON ',
#   '9749  ',
#   ''],
#  ['R8N=04:30',
#   'Fox Chase',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '4840  ',
#   '<_NEXT_MSG>05:01',
#   'Fox Chase',
#   '5',
#   ' 7 LATE',
#   'LOCAL                    ',
#   '4848  ',
#   '<_NEXT_MSG>05:25',
#   'Fox Chase',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '846   ',
#   '<_NEXT_MSG>05:40',
#   'Fox Chase',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '850   ',
#   ''],
#  ['R8S=04:49',
#   'Chestnut H West',
#   '3',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '839   ',
#   '<_NEXT_MSG>05:25',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '7841  ',
#   '<_NEXT_MSG>05:56',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '7843  ',
#   '<_NEXT_MSG>06:19',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '7845  ',
#   ''],
#  ['CC-N=04:22',
#   'West Trenton',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '2372  ',
#   '<_NEXT_MSG>04:24',
#   'Norristown',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '8246  ',
#   '<_NEXT_MSG>04:27',
#   'Warminster',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '5444  ',
#   '<_NEXT_MSG>04:30',
#   'Fox Chase',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '4840  ',
#   ''],
#  ['CC-S=04:19',
#   'Malvern',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '551   ',
#   '<_NEXT_MSG>04:29',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '449   ',
#   '<_NEXT_MSG>04:30',
#   'Elwyn',
#   '6',
#   ' 2 LATE',
#   'LOCAL                    ',
#   '9359  ',
#   '<_NEXT_MSG>04:34',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9245  ',
#   ''],
#  ['SERVICE=No outbound train service to Churchmans Crossing April 8 until May '
#   '31. Visit SEPTA.org for more info'],
#  ['TIMESTAMP=04/23/2019 16:19:02 PM']]

# %% [markdown]
# ### 3.1.4 Working with XML Responses

# %% [markdown]
# The Wikipedia API ([docs](https://en.wikipedia.org/api/rest_v1/)) returns results to various types of calls, and notably articles, in html format. Processing an html reponse into active form is more complex than JSON---the content won't necessarily translate into a native Python data type, much like XML. To work with this, we'll want to use a module called `BeautifulSoup` (install using `pip3 install bs4`), which we'll discuss in detail when we get to web scraping in __Chapter 5__. But explore, we can request the article for Philadelphia by constructing a search query and attempt to process with `xmltodict`, as introduced in __Chapter 1__.

# %%
response = requests.get("https://en.wikipedia.org/api/rest_v1/page/html/Philadelphia Pennsylvania")
    
pprint(response.text[:10000])
# Out:
# ('<!DOCTYPE html>\n'
#  '<html prefix="dc: http://purl.org/dc/terms/ mw: http://mediawiki.org/rdf/" '
#  'about="http://en.wikipedia.org/wiki/Special:Redirect/revision/893469306"><head '
#  'prefix="mwr: http://en.wikipedia.org/wiki/Special:Redirect/"><meta '
#  'property="mw:TimeUuid" content="1bc3c390-644b-11e9-9ad8-fab754f9212b"/><meta '
#  'charset="utf-8"/><meta property="mw:pageNamespace" content="0"/><meta '
#  'property="mw:pageId" content="50585"/><link rel="dc:replaces" '
#  'resource="mwr:revision/893415018"/><meta property="dc:modified" '
#  'content="2019-04-21T15:35:07.000Z"/><meta property="mw:revisionSHA1" '
#  'content="ac91cc4befdb7db83cad89147f580836d4593d76"/><meta '
#  'property="mw:html:version" content="2.1.0"/><link rel="dc:isVersionOf" '
#  'href="//en.wikipedia.org/wiki/Philadelphia"/><title>Philadelphia</title><base '
#  'href="//en.wikipedia.org/wiki/"/><link rel="stylesheet" '
#  'href="//en.wikipedia.org/w/load.php?modules=mediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.content.parsoid%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Csite.styles%7Cext.cite.style%7Cext.cite.styles%7Cmediawiki.page.gallery.styles%7Cext.kartographer.style&amp;only=styles&amp;skin=vector"/><!--[if '
#  'lt IE 9]><script '
#  'src="//en.wikipedia.org/w/load.php?modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><script>html5.addElements(\'figure-inline\');</script><![endif]--><meta '
#  'http-equiv="content-language" content="en"/><meta http-equiv="vary" '
#  'content="Accept"/></head><body id="mwAA" lang="en" class="mw-content-ltr '
#  'sitedir-ltr ltr mw-body-content parsoid-body mediawiki mw-parser-output" '
#  'dir="ltr"><section data-mw-section-id="0" id="mwAQ"><div role="note" '
#  'class="hatnote navigation-not-searchable" about="#mwt1" '
#  'typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"About","href":"./Template:About"},"params":{"1":{"wt":"the '
#  'Pennsylvania city"}},"i":0}}]}\' id="mwAg">This article is about the '
#  'Pennsylvania city. For other uses, see <a rel="mw:WikiLink" '
#  'href="./Philadelphia_(disambiguation)" title="Philadelphia '
#  '(disambiguation)">Philadelphia (disambiguation)</a>.</div>\n'
#  '<div role="note" class="hatnote navigation-not-searchable" about="#mwt2" '
#  'typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Redirect","href":"./Template:Redirect"},"params":{"1":{"wt":"Philly"}},"i":0}}]}\' '
#  'id="mwAw">"Philly" redirects here. For other uses, see <a rel="mw:WikiLink" '
#  'href="./Philly_(disambiguation)" title="Philly (disambiguation)">Philly '
#  '(disambiguation)</a>.</div>\n'
#  '<p id="mwBA"><span typeof="mw:Nowiki mw:Transclusion" about="#mwt3" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}\' '
#  'id="mwBQ"></span><link typeof="mw:Extension/indicator" about="#mwt3" '
#  'data-mw=\'{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#  'policy#semi|alt=Page semi-protected|This article is '
#  'semi-protected.]]"}}\'/><link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia" '
#  'about="#mwt3" id="mwBg"/>\n'
#  '<link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia" '
#  'about="#mwt4" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"pp-move-indef","href":"./Template:Pp-move-indef"},"params":{},"i":0}}]}\' '
#  'id="mwBw"/>\n'
#  '<span typeof="mw:Nowiki mw:Transclusion" about="#mwt5" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Use mdy '
#  'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"October '
#  '2017"}},"i":0}}]}\' id="mwCA"></span><link rel="mw:PageProp/Category" '
#  'href="./Category:Use_mdy_dates_from_October_2017" about="#mwt5" '
#  'id="mwCQ"/></p>\n'
#  '<div class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt6" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"short '
#  'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#  'city in Pennsylvania, United States"}},"i":0}}]}\' id="mwCg">Largest city in '
#  'Pennsylvania, United States</div><link rel="mw:PageProp/Category" '
#  'href="./Category:Articles_with_short_description" about="#mwt6" id="mwCw"/>\n'
#  '<div class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt16" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Infobox '
#  'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia, '
#  'Pennsylvania"},"official_name":{"wt":"City of '
#  'Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#  'city-county]]"},"etymology":{"wt":"[[Ancient Greek]]: [[wikt:φίλος|φίλος]] '
#  '&apos;&apos;phílos&apos;&apos; (beloved, dear) and [[wikt:ἀδελφός|ἀδελφός]] '
#  '&apos;&apos;adelphós&apos;&apos; (brother, '
#  'brotherly)"},"image_skyline":{"wt":"{{Photomontage\\n| '
#  'photo1a                   = BenjaminFranklinParkway2017.jpg{{!}}Eakins Oval '
#  'and Skyline (December 2017)\\n| photo2a                   = Independence '
#  'National Historical Park INDE0004 b.jpg{{!}}Liberty Bell and Independence '
#  'Hall\\n| photo2b                   = Philadelphia City Hall - 2.jpg{{!}}City '
#  'Hall\\n| photo3a                   = Skyline Philadelphia.JPG{{!}}Center '
#  'City skyline and Delaware River\\n| photo3b                   = '
#  'Elfreth&apos;s Alley.JPG{{!}}Elfreth&apos;s Alley\\n| '
#  'photo4a                   = Citizens Bank Park on August 6, '
#  '2009.jpg{{!}}Citizens Bank Park\\n| photo4b                   = Philly '
#  '(45).JPG{{!}}Lincoln Financial Field\\n| photo5a                   = '
#  'PhiladelphiaMuseumOfArt2017.jpg{{!}}Museum of Art\\n| '
#  'spacing                   = 2\\n| position                  = center\\n| '
#  'color_border              = black\\n| color                     = white\\n| '
#  'size                      = 270\\n| foot_montage              = Clockwise '
#  'from top: [[Philadelphia skyline|Center City skyline]] and [[Eakins Oval]] '
#  'in 2017; [[Philadelphia City Hall|City Hall]]; [[Elfreth&apos;s Alley]]; '
#  '[[Lincoln Financial Field]]; [[Philadelphia Museum of Art|Museum of Art]]; '
#  '[[Citizens Bank Park]]; [[Delaware River]] with [[Penn&apos;s Landing]] and '
#  'Center City in background; [[Liberty Bell]] and [[Independence '
#  'Hall]]\\n}}"},"nickname":{"wt":"\\"Philly\\", \\"The City of Brotherly '
#  'Love\\", \\"The [[Athens]] of America\\",&lt;ref>{{cite '
#  'web|url=http://www.librarycompany.org/artifacts/athens.htm|title=Art &amp; '
#  'Artifacts: Discover the Library Company’s Art and Artifact Collection – '
#  'Athens of America|website=librarycompany.org|publisher=The Library Company '
#  'of Philadelphia|accessdate=June 12, 2010}}&lt;/ref> &lt;small> and other '
#  '[[nicknames of Philadelphia]]&lt;/small>"},"motto":{"wt":"\\"Philadelphia '
#  'maneto\\" (\\"Let brotherly love endure\\" or \\"... '
#  'continue\\")&lt;ref>Robinson, Sam (November 5, 2013). '
#  '[https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal/ '
#  '\\"Behind Philadelphia Maneto: Dissecting The City Seal\\"]. '
#  '&apos;&apos;hiddencityphila.org&apos;&apos;. Hidden City Philadelphia. '
#  'Retrieved January 18, 2018.&lt;/ref>&lt;ref>McDevitt, John (May 5, 2015). '
#  '[http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/ '
#  '\\"Plaque Dedication Marks 120th Anniversary of Creation of Philadelphia’s '
#  'Flag\\"]. &apos;&apos;philadelphia.cbslocal.com&apos;&apos;. CBS '
#  'Broadcasting Inc. Retrieved January 18, '
#  '2018.&lt;/ref>"},"image_flag":{"wt":"Flag of Philadelphia, '
#  'Pennsylvania.svg"},"image_seal":{"wt":"Seal of Philadelphia, '
#  'Pennsylvania.svg"},"image_blank_emblem":{"wt":"City of Philadelphia '
#  'Logo.svg"},"blank_emblem_size":{"wt":"150px"},"blank_emblem_type":{"wt":"Logo"},"image_map":{"wt":"{{maplink|frame=yes|zoom=8|id=Q1345|type=shape-inverse|text=Interactive '
#  'map of Philadelphia}}"},"pushpin_map":{"wt":"Pennsylvania#USA#North '
#  'America"},"pushpin_label_position":{"wt":"left"},"pushpin_label":{"wt":"Philadelphia"},"pushpin_map_caption":{"wt":"Location '
#  'within Pennsylvania##Location within United States##Location within North '
#  'America"},"pushpin_relief":{"wt":"1"},"subdivision_type":{"wt":"[[List of '
#  'sovereign states|Country]]"},"subdivision_type2":{"wt":"[[U.S. '
#  'state|State]]"},"subdivision_type3":{"wt":"[[List of counties in '
#  'Pennsylvania|County]]"},"subdivision_name":{"wt":"{{nowrap|{{flagu|United '
#  'States}}}}"},"subdivision_name2":{"wt":"{{flag|Pennsylvania}}"},"subdivision_name3":{"wt":"[[Philadelphia '
#  'County, Pennsylvania|Philadelphia]]"},"subdivision_type4":{"wt":"Historic '
#  'countries"},"subdivision_name4":{"wt":"[[Kingdom of England]]&lt;br '
#  '/>[[Kingdom of Great '
#  'Britain]]"},"subdivision_type5":{"wt":"[[Colony|Historic '
#  'colony]]"},"subdivision_name5":{"wt":"[[Kingdom of Great Britain]] '
#  '[[Province of Pennsylvania]]"},"government_type":{"wt":"[[Mayor–council '
#  'government|Mayor–council]], [[consolidated '
#  'city-county]]"},"governing_body":{"wt":"[[Philadelphia City '
#  'Council]]"},"leader_title":{"wt":"[[List of mayors of '
#  'Philadelphia|Mayor]]"},"leader_name":{"wt":"[[Jim Kenney]] ([[Democratic '
#  'Party (United '
#  'States)|D]])"},"established_title":{"wt":"Founded"},"established_title1":{"wt":"[[Municipal '
#  'corporation|Incorporated]]"},"established_date":{"wt":"October 27, '
#  '1682"},"established_date1":{"wt":"October 25, '
#  '1701"},"founder":{"wt":"[[William Penn]]"},"area_magnitude":{"wt":"1 '
#  'E8"},"unit_pref":{"wt":"Imperial"},"area_total_sq_mi":{"wt":"142.70"},"area_total_km2":{"wt":"369.59"},"area_land_sq_mi":{"wt":"134.28"},"area_land_km2":{"wt":"347.78"},"area_water_sq_mi":{"wt":"8.42"},"area_water_km2":{"wt":"21.81"},"population_as_of":{"wt":"2018"},"population_footnotes":{"wt":"&lt;ref '
#  'name=\\"Pop Estimate\\">{{cite '
#  'web|url=https://www.census.gov/quickfacts/philadelphiacountypennsylvania|title= '
#  'QuickFacts Philadelphia County, Pennslvania|publisher=[[United States Census '
#  'Bureau]] |accessdate=April 18, '
#  '2019}}&lt;/ref>"},"population_total":{"wt":"1584138"},"population_rank":{"wt":"US '
#  'city: [[List of United States cities by '
#  'population|6th]]"},"population_metro":{"wt":"6,096,120 (US: [[List of '
#  'Metropolitan Statistical Areas|8th]])&lt;ref name=2017MSAest>{{cite '
#  'web|url=https://factfinder')

# %% [markdown]
# Since html is essentially a type of XML, we can try and convert the response into a dictionary using `xmltodict`. As you can see, in order to get the desired data out of the html, some studying of its structure is necessary. And since the structure of an html document is so particular, it will turn out to be a bit easier working with the html-specific parser in `BeautifulSoup` (__Chapter 5__). However, as we can see the content is there and navigable!

# %%
import xmltodict

parsed = xmltodict.parse(response.text)
pprint(parsed['html']['body']['section'][0])
# Out:
# OrderedDict([('@data-mw-section-id', '0'),
#              ('@id', 'mwAQ'),
#              ('div',
#               [OrderedDict([('@role', 'note'),
#                             ('@class', 'hatnote navigation-not-searchable'),
#                             ('@about', '#mwt1'),
#                             ('@typeof', 'mw:Transclusion'),
#                             ('@data-mw',
#                              '{"parts":[{"template":{"target":{"wt":"About","href":"./Template:About"},"params":{"1":{"wt":"the '
#                              'Pennsylvania city"}},"i":0}}]}'),
#                             ('@id', 'mwAg'),
#                             ('a',
#                              OrderedDict([('@rel', 'mw:WikiLink'),
#                                           ('@href',
#                                            './Philadelphia_(disambiguation)'),
#                                           ('@title',
#                                            'Philadelphia (disambiguation)'),
#                                           ('#text',
#                                            'Philadelphia (disambiguation)')])),
#                             ('#text',
#                              'This article is about the Pennsylvania city. For '
#                              'other uses, see .')]),
#                OrderedDict([('@role', 'note'),
#                             ('@class', 'hatnote navigation-not-searchable'),
#                             ('@about', '#mwt2'),
#                             ('@typeof', 'mw:Transclusion'),
#                             ('@data-mw',
#                              '{"parts":[{"template":{"target":{"wt":"Redirect","href":"./Template:Redirect"},"params":{"1":{"wt":"Philly"}},"i":0}}]}'),
#                             ('@id', 'mwAw'),
#                             ('a',
#                              OrderedDict([('@rel', 'mw:WikiLink'),
#                                           ('@href',
#                                            './Philly_(disambiguation)'),
#                                           ('@title', 'Philly (disambiguation)'),
#                                           ('#text',
#                                            'Philly (disambiguation)')])),
#                             ('#text',
#                              '"Philly" redirects here. For other uses, see '
#                              '.')]),
#                OrderedDict([('@class',
#                              'shortdescription nomobile noexcerpt noprint '
#                              'searchaux'),
#                             ('@style', 'display:none'),
#                             ('@about', '#mwt6'),
#                             ('@typeof', 'mw:Transclusion'),
#                             ('@data-mw',
#                              '{"parts":[{"template":{"target":{"wt":"short '
#                              'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#                              'city in Pennsylvania, United '
#                              'States"}},"i":0}}]}'),
#                             ('@id', 'mwCg'),
#                             ('#text',
#                              'Largest city in Pennsylvania, United States')]),
#                OrderedDict([('@class',
#                              'shortdescription nomobile noexcerpt noprint '
#                              'searchaux'),
#                             ('@style', 'display:none'),
#                             ('@about', '#mwt16'),
#                             ('@typeof', 'mw:Transclusion'),
#                             ('@data-mw',
#                              '{"parts":[{"template":{"target":{"wt":"Infobox '
#                              'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia, '
#                              'Pennsylvania"},"official_name":{"wt":"City of '
#                              'Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#                              'city-county]]"},"etymology":{"wt":"[[Ancient '
#                              "Greek]]: [[wikt:φίλος|φίλος]] ''phílos'' "
#                              '(beloved, dear) and [[wikt:ἀδελφός|ἀδελφός]] '
#                              "''adelphós'' (brother, "
#                              'brotherly)"},"image_skyline":{"wt":"{{Photomontage\\n| '
#                              'photo1a                   = '
#                              'BenjaminFranklinParkway2017.jpg{{!}}Eakins Oval '
#                              'and Skyline (December 2017)\\n| '
#                              'photo2a                   = Independence '
#                              'National Historical Park INDE0004 '
#                              'b.jpg{{!}}Liberty Bell and Independence Hall\\n| '
#                              'photo2b                   = Philadelphia City '
#                              'Hall - 2.jpg{{!}}City Hall\\n| '
#                              'photo3a                   = Skyline '
#                              'Philadelphia.JPG{{!}}Center City skyline and '
#                              'Delaware River\\n| photo3b                   = '
#                              "Elfreth's Alley.JPG{{!}}Elfreth's Alley\\n| "
#                              'photo4a                   = Citizens Bank Park '
#                              'on August 6, 2009.jpg{{!}}Citizens Bank Park\\n| '
#                              'photo4b                   = Philly '
#                              '(45).JPG{{!}}Lincoln Financial Field\\n| '
#                              'photo5a                   = '
#                              'PhiladelphiaMuseumOfArt2017.jpg{{!}}Museum of '
#                              'Art\\n| spacing                   = 2\\n| '
#                              'position                  = center\\n| '
#                              'color_border              = black\\n| '
#                              'color                     = white\\n| '
#                              'size                      = 270\\n| '
#                              'foot_montage              = Clockwise from top: '
#                              '[[Philadelphia skyline|Center City skyline]] and '
#                              '[[Eakins Oval]] in 2017; [[Philadelphia City '
#                              "Hall|City Hall]]; [[Elfreth's Alley]]; [[Lincoln "
#                              'Financial Field]]; [[Philadelphia Museum of '
#                              'Art|Museum of Art]]; [[Citizens Bank Park]]; '
#                              "[[Delaware River]] with [[Penn's Landing]] and "
#                              'Center City in background; [[Liberty Bell]] and '
#                              '[[Independence '
#                              'Hall]]\\n}}"},"nickname":{"wt":"\\"Philly\\", '
#                              '\\"The City of Brotherly Love\\", \\"The '
#                              '[[Athens]] of America\\",<ref>{{cite '
#                              'web|url=http://www.librarycompany.org/artifacts/athens.htm|title=Art '
#                              '& Artifacts: Discover the Library Company’s Art '
#                              'and Artifact Collection – Athens of '
#                              'America|website=librarycompany.org|publisher=The '
#                              'Library Company of Philadelphia|accessdate=June '
#                              '12, 2010}}</ref> <small> and other [[nicknames '
#                              'of '
#                              'Philadelphia]]</small>"},"motto":{"wt":"\\"Philadelphia '
#                              'maneto\\" (\\"Let brotherly love endure\\" or '
#                              '\\"... continue\\")<ref>Robinson, Sam (November '
#                              '5, 2013). '
#                              '[https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal/ '
#                              '\\"Behind Philadelphia Maneto: Dissecting The '
#                              'City Seal\\"]. \'\'hiddencityphila.org\'\'. '
#                              'Hidden City Philadelphia. Retrieved January 18, '
#                              '2018.</ref><ref>McDevitt, John (May 5, 2015). '
#                              '[http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/ '
#                              '\\"Plaque Dedication Marks 120th Anniversary of '
#                              'Creation of Philadelphia’s Flag\\"]. '
#                              "''philadelphia.cbslocal.com''. CBS Broadcasting "
#                              'Inc. Retrieved January 18, '
#                              '2018.</ref>"},"image_flag":{"wt":"Flag of '
#                              'Philadelphia, '
#                              'Pennsylvania.svg"},"image_seal":{"wt":"Seal of '
#                              'Philadelphia, '
#                              'Pennsylvania.svg"},"image_blank_emblem":{"wt":"City '
#                              'of Philadelphia '
#                              'Logo.svg"},"blank_emblem_size":{"wt":"150px"},"blank_emblem_type":{"wt":"Logo"},"image_map":{"wt":"{{maplink|frame=yes|zoom=8|id=Q1345|type=shape-inverse|text=Interactive '
#                              'map of '
#                              'Philadelphia}}"},"pushpin_map":{"wt":"Pennsylvania#USA#North '
#                              'America"},"pushpin_label_position":{"wt":"left"},"pushpin_label":{"wt":"Philadelphia"},"pushpin_map_caption":{"wt":"Location '
#                              'within Pennsylvania##Location within United '
#                              'States##Location within North '
#                              'America"},"pushpin_relief":{"wt":"1"},"subdivision_type":{"wt":"[[List '
#                              'of sovereign '
#                              'states|Country]]"},"subdivision_type2":{"wt":"[[U.S. '
#                              'state|State]]"},"subdivision_type3":{"wt":"[[List '
#                              'of counties in '
#                              'Pennsylvania|County]]"},"subdivision_name":{"wt":"{{nowrap|{{flagu|United '
#                              'States}}}}"},"subdivision_name2":{"wt":"{{flag|Pennsylvania}}"},"subdivision_name3":{"wt":"[[Philadelphia '
#                              'County, '
#                              'Pennsylvania|Philadelphia]]"},"subdivision_type4":{"wt":"Historic '
#                              'countries"},"subdivision_name4":{"wt":"[[Kingdom '
#                              'of England]]<br />[[Kingdom of Great '
#                              'Britain]]"},"subdivision_type5":{"wt":"[[Colony|Historic '
#                              'colony]]"},"subdivision_name5":{"wt":"[[Kingdom '
#                              'of Great Britain]] [[Province of '
#                              'Pennsylvania]]"},"government_type":{"wt":"[[Mayor–council '
#                              'government|Mayor–council]], [[consolidated '
#                              'city-county]]"},"governing_body":{"wt":"[[Philadelphia '
#                              'City Council]]"},"leader_title":{"wt":"[[List of '
#                              'mayors of '
#                              'Philadelphia|Mayor]]"},"leader_name":{"wt":"[[Jim '
#                              'Kenney]] ([[Democratic Party (United '
#                              'States)|D]])"},"established_title":{"wt":"Founded"},"established_title1":{"wt":"[[Municipal '
#                              'corporation|Incorporated]]"},"established_date":{"wt":"October '
#                              '27, 1682"},"established_date1":{"wt":"October '
#                              '25, 1701"},"founder":{"wt":"[[William '
#                              'Penn]]"},"area_magnitude":{"wt":"1 '
#                              'E8"},"unit_pref":{"wt":"Imperial"},"area_total_sq_mi":{"wt":"142.70"},"area_total_km2":{"wt":"369.59"},"area_land_sq_mi":{"wt":"134.28"},"area_land_km2":{"wt":"347.78"},"area_water_sq_mi":{"wt":"8.42"},"area_water_km2":{"wt":"21.81"},"population_as_of":{"wt":"2018"},"population_footnotes":{"wt":"<ref '
#                              'name=\\"Pop Estimate\\">{{cite '
#                              'web|url=https://www.census.gov/quickfacts/philadelphiacountypennsylvania|title= '
#                              'QuickFacts Philadelphia County, '
#                              'Pennslvania|publisher=[[United States Census '
#                              'Bureau]] |accessdate=April 18, '
#                              '2019}}</ref>"},"population_total":{"wt":"1584138"},"population_rank":{"wt":"US '
#                              'city: [[List of United States cities by '
#                              'population|6th]]"},"population_metro":{"wt":"6,096,120 '
#                              '(US: [[List of Metropolitan Statistical '
#                              'Areas|8th]])<ref name=2017MSAest>{{cite '
#                              'web|url=https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?pid=PEP_2017_PEPANNCHG.US24PR&prodType=table '
#                              '|title=Estimates of Resident Population Change '
#                              'and Rankings: July 1, 2016 to July 1, 2017 – '
#                              'United States – Metropolitan Statistical Area; '
#                              'and for Puerto Rico; 2017 Population Estimates '
#                              '|publisher=[[United States Census Bureau]], '
#                              'Population Division |date=March 2018 '
#                              '|accessdate=May 14, '
#                              '2018}}</ref>"},"population_density_km2":{"wt":"4554.95"},"population_density_sq_mi":{"wt":"11797.27"},"population_blank1_title":{"wt":"[[Combined '
#                              'statistical '
#                              'area|CSA]]"},"population_blank1":{"wt":"7,206,807 '
#                              '(US: [[List of Combined Statistical '
#                              'Areas|8th]])<ref name=2017CSAest>{{cite '
#                              'web|url=https://factfinder.census.gov/bkmk/table/1.0/en/PEP/2017/GCTPEPANNR.US41PR '
#                              '|title=Annual Estimates of the Resident '
#                              'Population: April 1, 2010 to July 1, 2017 – '
#                              'United States – Combined Statistical Area; and '
#                              'for Puerto Rico; 2017 Population Estimates '
#                              '|publisher=[[United States Census Bureau]], '
#                              'Population Division |date=March 2018 '
#                              '|accessdate=May 14, '
#                              '2018}}</ref>"},"population_blank2_title":{"wt":"[[Demonym]]"},"population_blank2":{"wt":"Philadelphian"},"timezone":{"wt":"[[North '
#                              'American Eastern Time '
#                              'Zone|EST]]"},"utc_offset":{"wt":"-5"},"timezone_DST":{"wt":"[[Eastern '
#                              'Daylight '
#                              'Time|EDT]]"},"utc_offset_DST":{"wt":"-4"},"postal_code_type":{"wt":"[[ZIP '
#                              'code]]"},"postal_code":{"wt":"19092-19093, '
#                              '19099, 191xx"},"area_codes":{"wt":"[[Area codes '
#                              '215, 267, and 445|215, 267, '
#                              '445]]"},"coordinates":{"wt":"{{coord|39|57|10|N|75|09|49|W|format=dms|region:US-PA|display=inline,title}}"},"elevation_m":{"wt":"12"},"elevation_ft":{"wt":"39"},"blank_name":{"wt":"[[Federal '
#                              'Information Processing Standards|FIPS '
#                              'code]]"},"blank_info":{"wt":"42-60000"},"blank1_name":{"wt":"[[Geographic '
#                              'Names Information System|GNIS]] feature '
#                              'ID"},"blank1_info":{"wt":"1215531<ref>{{cite '
#                              'web|url=http://geonames.usgs.gov/apex/f?p=136:3:0::NO::P3_FID,P3_TITLE:1215531,City%20of%20Philadelphia|accessdate=January '
#                              '31, 2008|title=US Board on Geographic '
#                              'Names|publisher=[[United States Geological '
#                              'Survey]]|date=February 2, '
#                              '2015}}</ref>"},"blank_name_sec2":{"wt":"Major '
#                              'airport"},"blank_info_sec2":{"wt":"[[Philadelphia '
#                              'International '
#                              'Airport]]"},"blank1_name_sec2":{"wt":"[[Interstate '
#                              'Highway '
#                              'System|Interstates]]"},"blank1_info_sec2":{"wt":"[[File:I-76.svg|26px|link=Interstate '
#                              '76 in Pennsylvania]] '
#                              '[[File:I-95.svg|26px|link=Interstate 95 in '
#                              'Pennsylvania]] '
#                              '[[File:I-676.svg|32px|link=Interstate '
#                              '676]]"},"blank2_name_sec2":{"wt":"[[United '
#                              'States Numbered Highway System|U.S. '
#                              'Routes]]"},"blank2_info_sec2":{"wt":"[[File:US '
#                              '1.svg|26px|link=U.S. Route 1 in Pennsylvania]] '
#                              '[[File:US 13.svg|26px|link=U.S. Route 13 in '
#                              'Pennsylvania]] [[File:US 30.svg|26px|link=U.S. '
#                              'Route 30 in '
#                              'Pennsylvania]]"},"blank3_name_sec2":{"wt":"[[Commuter '
#                              'rail]]"},"blank3_info_sec2":{"wt":"[[SEPTA '
#                              'Regional Rail]], [[NJ Transit Rail Operations|NJ '
#                              'Transit]]"},"blank4_name_sec2":{"wt":"[[Rapid '
#                              'transit]]"},"blank4_info_sec2":{"wt":"[[Broad '
#                              'Street Line]], [[Market–Frankford Line]], '
#                              '[[PATCO '
#                              'Speedline]]"},"website":{"wt":"[http://www.phila.gov/ '
#                              'www.phila.gov]"},"footnotes":{"wt":""},"pop_est_as_of":{"wt":"2017"},"pop_est_footnotes":{"wt":"<ref '
#                              'name=\\"USCensusEst2017\\">{{cite '
#                              'web|url=https://www.census.gov/programs-surveys/popest/data/tables.2017.html|title=Population '
#                              'and Housing Unit Estimates|accessdate=March 24, '
#                              '2018}}</ref>"},"population_est":{"wt":"1580863"},"area_footnotes":{"wt":"<ref '
#                              'name=\\"CenPopGazetteer2016\\">{{cite '
#                              'web|title=2017 U.S. Gazetteer '
#                              'Files|url=https://www2.census.gov/geo/docs/maps-data/data/gazetteer/2017_Gazetteer/2017_gaz_place_42.txt|publisher=United '
#                              'States Census Bureau|accessdate=Mar 24, '
#                              '2019}}</ref>"}},"i":0}}]}'),
#                             ('@id', 'mwDA'),
#                             ('#text', 'Consolidated city-county')]),
#                OrderedDict([('@class', 'toclimit-3'),
#                             ('@about', '#mwt89'),
#                             ('@id', 'mwXg'),
#                             ('meta',
#                              OrderedDict([('@property',
#                                            'mw:PageProp/toc')]))])]),
#              ('p',
#               [OrderedDict([('@id', 'mwBA'),
#                             ('span',
#                              [OrderedDict([('@typeof',
#                                             'mw:Nowiki mw:Transclusion'),
#                                            ('@about', '#mwt3'),
#                                            ('@data-mw',
#                                             '{"parts":[{"template":{"target":{"wt":"pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}'),
#                                            ('@id', 'mwBQ')]),
#                               OrderedDict([('@typeof',
#                                             'mw:Nowiki mw:Transclusion'),
#                                            ('@about', '#mwt5'),
#                                            ('@data-mw',
#                                             '{"parts":[{"template":{"target":{"wt":"Use '
#                                             'mdy '
#                                             'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"October '
#                                             '2017"}},"i":0}}]}'),
#                                            ('@id', 'mwCA')])]),
#                             ('link',
#                              [OrderedDict([('@typeof',
#                                             'mw:Extension/indicator'),
#                                            ('@about', '#mwt3'),
#                                            ('@data-mw',
#                                             '{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#                                             'policy#semi|alt=Page '
#                                             'semi-protected|This article is '
#                                             'semi-protected.]]"}}')]),
#                               OrderedDict([('@rel', 'mw:PageProp/Category'),
#                                            ('@href',
#                                             './Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia'),
#                                            ('@about', '#mwt3'),
#                                            ('@id', 'mwBg')]),
#                               OrderedDict([('@rel', 'mw:PageProp/Category'),
#                                            ('@href',
#                                             './Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia'),
#                                            ('@about', '#mwt4'),
#                                            ('@typeof', 'mw:Transclusion'),
#                                            ('@data-mw',
#                                             '{"parts":[{"template":{"target":{"wt":"pp-move-indef","href":"./Template:Pp-move-indef"},"params":{},"i":0}}]}'),
#                                            ('@id', 'mwBw')]),
#                               OrderedDict([('@rel', 'mw:PageProp/Category'),
#                                            ('@href',
#                                             './Category:Use_mdy_dates_from_October_2017'),
#                                            ('@about', '#mwt5'),
#                                            ('@id', 'mwCQ')])])]),
#                OrderedDict([('@id', 'mwDg'),
#                             ('b',
#                              [OrderedDict([('@id', 'mwDw'),
#                                            ('#text', 'Philadelphia')]),
#                               OrderedDict([('@id', 'mwEA'),
#                                            ('#text', 'Philly')])]),
#                             ('a',
#                              [OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './U.S._state'),
#                                            ('@title', 'U.S. state'),
#                                            ('@id', 'mwEQ'),
#                                            ('#text', 'U.S. state')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Commonwealth_(U.S._state)'),
#                                            ('@title',
#                                             'Commonwealth (U.S. state)'),
#                                            ('@id', 'mwEg'),
#                                            ('#text', 'Commonwealth')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Pennsylvania'),
#                                            ('@title', 'Pennsylvania'),
#                                            ('@id', 'mwEw'),
#                                            ('#text', 'Pennsylvania')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './List_of_United_States_cities_by_population'),
#                                            ('@title',
#                                             'List of United States cities by '
#                                             'population'),
#                                            ('@id', 'mwFA'),
#                                            ('#text',
#                                             'sixth-most populous U.S. city')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Act_of_Consolidation,_1854'),
#                                            ('@title',
#                                             'Act of Consolidation, 1854'),
#                                            ('@id', 'mwFQ'),
#                                            ('#text', 'Since 1854')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Philadelphia_County,_Pennsylvania'),
#                                            ('@title',
#                                             'Philadelphia County, '
#                                             'Pennsylvania'),
#                                            ('@id', 'mwFg'),
#                                            ('#text', 'Philadelphia County')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './List_of_counties_in_Pennsylvania'),
#                                            ('@title',
#                                             'List of counties in Pennsylvania'),
#                                            ('@id', 'mwFw'),
#                                            ('#text', 'most populous county')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './List_of_metropolitan_statistical_areas'),
#                                            ('@title',
#                                             'List of metropolitan statistical '
#                                             'areas'),
#                                            ('@id', 'mwGA'),
#                                            ('#text',
#                                             'eighth-largest U.S. metropolitan '
#                                             'statistical area')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Delaware_Valley'),
#                                            ('@title', 'Delaware Valley'),
#                                            ('@id', 'mwHA'),
#                                            ('#text', 'Delaware Valley')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Delaware_River'),
#                                            ('@title', 'Delaware River'),
#                                            ('@id', 'mwHQ'),
#                                            ('#text', 'Delaware')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Schuylkill_River'),
#                                            ('@title', 'Schuylkill River'),
#                                            ('@id', 'mwHg'),
#                                            ('#text', 'Schuylkill')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Northeast_megalopolis'),
#                                            ('@title', 'Northeast megalopolis'),
#                                            ('@id', 'mwHw'),
#                                            ('#text', 'Northeast megalopolis')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Combined_statistical_area#List_of_combined_statistical_areas'),
#                                            ('@title',
#                                             'Combined statistical area'),
#                                            ('@id', 'mwIQ'),
#                                            ('#text',
#                                             'eighth-largest combined '
#                                             'statistical area')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './United_States'),
#                                            ('@title', 'United States'),
#                                            ('@id', 'mwIg'),
#                                            ('#text', 'United States')])]),
#                             ('sup',
#                              [OrderedDict([('@about', '#mwt22'),
#                                            ('@class', 'mw-ref'),
#                                            ('@id', 'cite_ref-Pop_Estimate_5-1'),
#                                            ('@rel', 'dc:references'),
#                                            ('@typeof', 'mw:Extension/ref'),
#                                            ('@data-mw',
#                                             '{"name":"ref","attrs":{"name":"Pop '
#                                             'Estimate"}}'),
#                                            ('a',
#                                             OrderedDict([('@href',
#                                                           './Philadelphia#cite_note-Pop_Estimate-5'),
#                                                          ('@style',
#                                                           'counter-reset: '
#                                                           'mw-Ref 5;'),
#                                                          ('span',
#                                                           OrderedDict([('@class',
#                                                                         'mw-reflink-text'),
#                                                                        ('#text',
#                                                                         '[5]')]))]))]),
#                               OrderedDict([('@class',
#                                             'plainlinks noexcerpt noprint '
#                                             'asof-tag update'),
#                                            ('@style', 'display:none;'),
#                                            ('@about', '#mwt20'),
#                                            ('a',
#                                             OrderedDict([('@rel', 'mw:ExtLink'),
#                                                          ('@href',
#                                                           '//en.wikipedia.org/w/index.php?title=Philadelphia&action=edit'),
#                                                          ('@class',
#                                                           'external text'),
#                                                          ('span',
#                                                           [OrderedDict([('@typeof',
#                                                                          'mw:Entity'),
#                                                                         ('#text',
#                                                                          '[')]),
#                                                            OrderedDict([('@typeof',
#                                                                          'mw:Entity'),
#                                                                         ('#text',
#                                                                          ']')])]),
#                                                          ('#text',
#                                                           'update')]))]),
#                               OrderedDict([('@about', '#mwt24'),
#                                            ('@class', 'mw-ref'),
#                                            ('@id', 'cite_ref-2017MSAest_7-1'),
#                                            ('@rel', 'dc:references'),
#                                            ('@typeof', 'mw:Extension/ref'),
#                                            ('@data-mw',
#                                             '{"name":"ref","attrs":{"name":"2017MSAest"}}'),
#                                            ('a',
#                                             OrderedDict([('@href',
#                                                           './Philadelphia#cite_note-2017MSAest-7'),
#                                                          ('@style',
#                                                           'counter-reset: '
#                                                           'mw-Ref 7;'),
#                                                          ('span',
#                                                           OrderedDict([('@class',
#                                                                         'mw-reflink-text'),
#                                                                        ('#text',
#                                                                         '[7]')]))]))]),
#                               OrderedDict([('@about', '#mwt26'),
#                                            ('@class', 'mw-ref'),
#                                            ('@id', 'cite_ref-2017CSAest_8-1'),
#                                            ('@rel', 'dc:references'),
#                                            ('@typeof', 'mw:Extension/ref'),
#                                            ('@data-mw',
#                                             '{"name":"ref","attrs":{"name":"2017CSAest"}}'),
#                                            ('a',
#                                             OrderedDict([('@href',
#                                                           './Philadelphia#cite_note-2017CSAest-8'),
#                                                          ('@style',
#                                                           'counter-reset: '
#                                                           'mw-Ref 8;'),
#                                                          ('span',
#                                                           OrderedDict([('@class',
#                                                                         'mw-reflink-text'),
#                                                                        ('#text',
#                                                                         '[8]')]))]))])]),
#                             ('span',
#                              [OrderedDict([('@typeof', 'mw:Entity'),
#                                            ('@id', 'mwGQ')]),
#                               OrderedDict([('@about', '#mwt20'),
#                                            ('@typeof', 'mw:Transclusion'),
#                                            ('@data-mw',
#                                             '{"parts":[{"template":{"target":{"wt":"as '
#                                             'of","href":"./Template:As_of"},"params":{"1":{"wt":"2017"},"lc":{"wt":"y"}},"i":0}}]}'),
#                                            ('@id', 'mwGg'),
#                                            ('#text', 'as of 2017')]),
#                               OrderedDict([('@typeof', 'mw:Nowiki'),
#                                            ('@about', '#mwt20')]),
#                               OrderedDict([('@typeof', 'mw:Entity'),
#                                            ('@id', 'mwIA')])]),
#                             ('link',
#                              [OrderedDict([('@rel', 'mw:PageProp/Category'),
#                                            ('@href',
#                                             './Category:Articles_containing_potentially_dated_statements_from_2017'),
#                                            ('@about', '#mwt20')]),
#                               OrderedDict([('@rel', 'mw:PageProp/Category'),
#                                            ('@href',
#                                             './Category:All_articles_containing_potentially_dated_statements'),
#                                            ('@about', '#mwt20'),
#                                            ('@id', 'mwGw')])]),
#                             ('#text',
#                              ', known colloquially as , is the largest city in '
#                              'the  and  of , and the , with a 2018 '
#                              'census-estimated population of 1,584,138. , the '
#                              'city has been coterminous with , the  in '
#                              'Pennsylvania and the urban core of the , with '
#                              'over 6million residents . Philadelphia is also '
#                              'the economic and cultural anchor of the greater '
#                              ', located along the lower  and  Rivers, within '
#                              "the . The Delaware Valley's population of "
#                              '7.2million ranks it as the  in the .')]),
#                OrderedDict([('@id', 'mwIw'),
#                             ('a',
#                              [OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './William_Penn'),
#                                            ('@title', 'William Penn'),
#                                            ('@id', 'mwJA'),
#                                            ('#text', 'William Penn')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Quakers'),
#                                            ('@title', 'Quakers'),
#                                            ('@id', 'mwJQ'),
#                                            ('#text', 'Quaker')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Province_of_Pennsylvania'),
#                                            ('@title',
#                                             'Province of Pennsylvania'),
#                                            ('@id', 'mwJg'),
#                                            ('#text', 'Pennsylvania Colony')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './American_Revolution'),
#                                            ('@title', 'American Revolution'),
#                                            ('@id', 'mwJw'),
#                                            ('#text', 'American Revolution')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Founding_Fathers_of_the_United_States'),
#                                            ('@title',
#                                             'Founding Fathers of the United '
#                                             'States'),
#                                            ('@id', 'mwKA'),
#                                            ('#text',
#                                             'Founding Fathers of the United '
#                                             'States')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './United_States_Declaration_of_Independence'),
#                                            ('@title',
#                                             'United States Declaration of '
#                                             'Independence'),
#                                            ('@id', 'mwKQ'),
#                                            ('#text',
#                                             'Declaration of Independence')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Second_Continental_Congress'),
#                                            ('@title',
#                                             'Second Continental Congress'),
#                                            ('@id', 'mwKg'),
#                                            ('#text',
#                                             'Second Continental Congress')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './United_States_Constitution'),
#                                            ('@title',
#                                             'United States Constitution'),
#                                            ('@id', 'mwKw'),
#                                            ('#text', 'Constitution')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Constitutional_Convention_(United_States)'),
#                                            ('@title',
#                                             'Constitutional Convention (United '
#                                             'States)'),
#                                            ('@id', 'mwLA'),
#                                            ('#text',
#                                             'Philadelphia Convention')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './American_Revolutionary_War'),
#                                            ('@title',
#                                             'American Revolutionary War'),
#                                            ('@id', 'mwLQ'),
#                                            ('#text', 'Revolutionary War')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './First_Continental_Congress'),
#                                            ('@title',
#                                             'First Continental Congress'),
#                                            ('@id', 'mwLg'),
#                                            ('#text',
#                                             'First Continental Congress')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Liberty_Bell#Early_days_(1754–1846)'),
#                                            ('@title', 'Liberty Bell'),
#                                            ('@id', 'mwLw'),
#                                            ('#text', 'Liberty Bell')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Battle_of_Germantown'),
#                                            ('@title', 'Battle of Germantown'),
#                                            ('@id', 'mwMA'),
#                                            ('#text', 'Battle of Germantown')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Siege_of_Fort_Mifflin'),
#                                            ('@title', 'Siege of Fort Mifflin'),
#                                            ('@id', 'mwMQ'),
#                                            ('#text', 'Siege of Fort Mifflin')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './New_York_City'),
#                                            ('@title', 'New York City'),
#                                            ('@id', 'mwMg'),
#                                            ('#text', 'New York City')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './List_of_capitals_in_the_United_States'),
#                                            ('@title',
#                                             'List of capitals in the United '
#                                             'States'),
#                                            ('@id', 'mwMw'),
#                                            ('#text', 'capitals')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Washington,_D.C.'),
#                                            ('@title', 'Washington, D.C.'),
#                                            ('@id', 'mwNA'),
#                                            ('#text', 'Washington, D.C.')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './19th_century'),
#                                            ('@title', '19th century'),
#                                            ('@id', 'mwNQ'),
#                                            ('#text', '19th century')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './Immigration'),
#                                            ('@title', 'Immigration'),
#                                            ('@id', 'mwNg'),
#                                            ('#text', 'immigrants')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './20th_century'),
#                                            ('@title', '20th century'),
#                                            ('@id', 'mwOQ'),
#                                            ('#text', '20th century')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './African_Americans'),
#                                            ('@title', 'African Americans'),
#                                            ('@id', 'mwOg'),
#                                            ('#text', 'African Americans')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Great_Migration_(African_American)'),
#                                            ('@title',
#                                             'Great Migration (African '
#                                             'American)'),
#                                            ('@id', 'mwOw'),
#                                            ('#text', 'Great Migration')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href', './American_Civil_War'),
#                                            ('@title', 'American Civil War'),
#                                            ('@id', 'mwPA'),
#                                            ('#text', 'Civil War')]),
#                               OrderedDict([('@rel', 'mw:WikiLink'),
#                                            ('@href',
#                                             './Puerto_Ricans_in_Philadelphia'),
#                                            ('@title',
#                                             'Puerto Ricans in Philadelphia'),
#                                            ('@id', 'mwPQ'),
#                                            ('#text', 'Puerto Ricans')])]),
#                             ('sup',
#                              [OrderedDict([('@about', '#mwt1185'),
# ...
#                                                                                                                   '26'),
#                                                                                                                  ('@width',
#                                                                                                                   '26'),
#                                                                                                                  ('@srcset',
#                                                                                                                   '//upload.wikimedia.org/wikipedia/commons/thumb/e/e8/US_13.svg/52px-US_13.svg.png '
#                                                                                                                   '2x, '
#                                                                                                                   '//upload.wikimedia.org/wikipedia/commons/thumb/e/e8/US_13.svg/39px-US_13.svg.png '
#                                                                                                                   '1.5x')]))]))]),
#                                                                         OrderedDict([('@typeof',
#                                                                                       'mw:Image'),
#                                                                                      ('a',
#                                                                                       OrderedDict([('@href',
#                                                                                                     './U.S._Route_30_in_Pennsylvania'),
#                                                                                                    ('img',
#                                                                                                     OrderedDict([('@resource',
#                                                                                                                   './File:US_30.svg'),
#                                                                                                                  ('@src',
#                                                                                                                   '//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/US_30.svg/26px-US_30.svg.png'),
#                                                                                                                  ('@data-file-width',
#                                                                                                                   '600'),
#                                                                                                                  ('@data-file-height',
#                                                                                                                   '600'),
#                                                                                                                  ('@data-file-type',
#                                                                                                                   'drawing'),
#                                                                                                                  ('@height',
#                                                                                                                   '26'),
#                                                                                                                  ('@width',
#                                                                                                                   '26'),
#                                                                                                                  ('@srcset',
#                                                                                                                   '//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/US_30.svg/52px-US_30.svg.png '
#                                                                                                                   '2x, '
#                                                                                                                   '//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/US_30.svg/39px-US_30.svg.png '
#                                                                                                                   '1.5x')]))]))])])]))]),
#                                            OrderedDict([('@class', 'mergedrow'),
#                                                         ('th',
#                                                          OrderedDict([('@scope',
#                                                                        'row'),
#                                                                       ('a',
#                                                                        OrderedDict([('@rel',
#                                                                                      'mw:WikiLink'),
#                                                                                     ('@href',
#                                                                                      './Commuter_rail'),
#                                                                                     ('@title',
#                                                                                      'Commuter '
#                                                                                      'rail'),
#                                                                                     ('#text',
#                                                                                      'Commuter '
#                                                                                      'rail')]))])),
#                                                         ('td',
#                                                          OrderedDict([('a',
#                                                                        [OrderedDict([('@rel',
#                                                                                       'mw:WikiLink'),
#                                                                                      ('@href',
#                                                                                       './SEPTA_Regional_Rail'),
#                                                                                      ('@title',
#                                                                                       'SEPTA '
#                                                                                       'Regional '
#                                                                                       'Rail'),
#                                                                                      ('#text',
#                                                                                       'SEPTA '
#                                                                                       'Regional '
#                                                                                       'Rail')]),
#                                                                         OrderedDict([('@rel',
#                                                                                       'mw:WikiLink'),
#                                                                                      ('@href',
#                                                                                       './NJ_Transit_Rail_Operations'),
#                                                                                      ('@title',
#                                                                                       'NJ '
#                                                                                       'Transit '
#                                                                                       'Rail '
#                                                                                       'Operations'),
#                                                                                      ('#text',
#                                                                                       'NJ '
#                                                                                       'Transit')])]),
#                                                                       ('#text',
#                                                                        ',')]))]),
#                                            OrderedDict([('@class', 'mergedrow'),
#                                                         ('th',
#                                                          OrderedDict([('@scope',
#                                                                        'row'),
#                                                                       ('a',
#                                                                        OrderedDict([('@rel',
#                                                                                      'mw:WikiLink'),
#                                                                                     ('@href',
#                                                                                      './Rapid_transit'),
#                                                                                     ('@title',
#                                                                                      'Rapid '
#                                                                                      'transit'),
#                                                                                     ('#text',
#                                                                                      'Rapid '
#                                                                                      'transit')]))])),
#                                                         ('td',
#                                                          OrderedDict([('a',
#                                                                        [OrderedDict([('@rel',
#                                                                                       'mw:WikiLink'),
#                                                                                      ('@href',
#                                                                                       './Broad_Street_Line'),
#                                                                                      ('@title',
#                                                                                       'Broad '
#                                                                                       'Street '
#                                                                                       'Line'),
#                                                                                      ('#text',
#                                                                                       'Broad '
#                                                                                       'Street '
#                                                                                       'Line')]),
#                                                                         OrderedDict([('@rel',
#                                                                                       'mw:WikiLink'),
#                                                                                      ('@href',
#                                                                                       './Market–Frankford_Line'),
#                                                                                      ('@title',
#                                                                                       'Market–Frankford '
#                                                                                       'Line'),
#                                                                                      ('#text',
#                                                                                       'Market–Frankford '
#                                                                                       'Line')]),
#                                                                         OrderedDict([('@rel',
#                                                                                       'mw:WikiLink'),
#                                                                                      ('@href',
#                                                                                       './PATCO_Speedline'),
#                                                                                      ('@title',
#                                                                                       'PATCO '
#                                                                                       'Speedline'),
#                                                                                      ('#text',
#                                                                                       'PATCO '
#                                                                                       'Speedline')])]),
#                                                                       ('#text',
#                                                                        ', '
#                                                                        ',')]))]),
#                                            OrderedDict([('@class',
#                                                          'mergedtoprow'),
#                                                         ('th',
#                                                          OrderedDict([('@scope',
#                                                                        'row'),
#                                                                       ('#text',
#                                                                        'Website')])),
#                                                         ('td',
#                                                          OrderedDict([('a',
#                                                                        OrderedDict([('@rel',
#                                                                                      'mw:ExtLink'),
#                                                                                     ('@href',
#                                                                                      'http://www.phila.gov/'),
#                                                                                     ('@class',
#                                                                                      'external '
#                                                                                      'text'),
#                                                                                     ('#text',
#                                                                                      'www.phila.gov')]))]))])])]))])),
#              ('style',
#               OrderedDict([('@data-mw-deduplicate',
#                             'TemplateStyles:r886046785'),
#                            ('@typeof',
#                             'mw:Extension/templatestyles mw:Transclusion'),
#                            ('@about', '#mwt89'),
#                            ('@data-mw',
#                             '{"parts":[{"template":{"target":{"wt":"TOC '
#                             'limit","href":"./Template:TOC_limit"},"params":{},"i":0}}]}'),
#                            ('@id', 'mwXQ'),
#                            ('#text',
#                             '.mw-parser-output .toclimit-2 .toclevel-1 '
#                             'ul,.mw-parser-output .toclimit-3 .toclevel-2 '
#                             'ul,.mw-parser-output .toclimit-4 .toclevel-3 '
#                             'ul,.mw-parser-output .toclimit-5 .toclevel-4 '
#                             'ul,.mw-parser-output .toclimit-6 .toclevel-5 '
#                             'ul,.mw-parser-output .toclimit-7 .toclevel-6 '
#                             'ul{display:none}')]))])

# %% [markdown]
# ## 3.2 API authentication
# The GitHub and SEPTA examples we've looked at so far are APIs that don't require any authentication to access. Anyone can send a request to these APIs and receive a response. There are, however, quite a few APIs that require the user to have some authentication. This authentication usually takes the form of an access token that needs to be obtained from the API provider before making requests.
#
# ### 3.2.1 Example: Sportradar
# As an example, we'll take a look at one of the [Sportradar APIs](https://developer.sportradar.com). Sportradar has APIs for a number of different sports.
#
# In order to use any of their APIs, Sportradar requires you to open a developer account and register an app. Only then you are granted an access token or "API key", which you must plug in to any requests you make.
#
# The steps to obtain an API key from Sportradar are:
# 1. Sign up as a developer [here](https://developer.sportradar.com/member/register)
# 2. Sign in to your account and go your [account page](https://developer.sportradar.com/member/my-account)
# 3. Go to your [applications page](https://developer.sportradar.com/apps/myapps)
# 4. Register a new application and select the API keys you need
#
# We'll use the Sportradar Soccer API to obtain the match schedule for an English soccer team, Manchester City.
#
# First, we'll construct the request address using the API key.

# %%
soccer_key = ""

# %%
# format: "https://api.sportradar.us/soccer-xt3/eu/en/teams/TEAM_ID/schedule.json?api_key=API_KEY"
address = "https://api.sportradar.us/soccer-xt3/eu/en/teams/sr:competitor:17/schedule.json?api_key=" + soccer_key

# %%
resp = requests.get(address)

# %%
result = resp.json()

# %%
pprint(result)
# Out:
# {'generated_at': '2019-04-23T20:19:24+00:00',
#  'schedule': [{'competitors': [{'abbreviation': 'MUN',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:35',
#                                 'name': 'Manchester United',
#                                 'qualifier': 'home'},
#                                {'abbreviation': 'MCI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:17',
#                                 'name': 'Manchester City',
#                                 'qualifier': 'away'}],
#                'id': 'sr:match:17487549',
#                'scheduled': '2019-04-24T19:00:00+00:00',
#                'season': {'end_date': '2019-05-13',
#                           'id': 'sr:season:54571',
#                           'name': 'Premier League 18/19',
#                           'start_date': '2018-08-10',
#                           'tournament_id': 'sr:tournament:17',
#                           'year': '18/19'},
#                'start_time_tbd': False,
#                'status': 'not_started',
#                'tournament': {'category': {'country_code': 'ENG',
#                                            'id': 'sr:category:1',
#                                            'name': 'England'},
#                               'id': 'sr:tournament:17',
#                               'name': 'Premier League',
#                               'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#                'tournament_round': {'number': 31,
#                                     'phase': 'regular season',
#                                     'type': 'group'},
#                'venue': {'capacity': 75635,
#                          'city_name': 'Manchester',
#                          'country_code': 'ENG',
#                          'country_name': 'England',
#                          'id': 'sr:venue:9',
#                          'map_coordinates': '53.463150,-2.291444',
#                          'name': 'Old Trafford'}},
#               {'competitors': [{'abbreviation': 'BUR',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:6',
#                                 'name': 'Burnley FC',
#                                 'qualifier': 'home'},
#                                {'abbreviation': 'MCI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:17',
#                                 'name': 'Manchester City',
#                                 'qualifier': 'away'}],
#                'id': 'sr:match:14736957',
#                'scheduled': '2019-04-28T13:05:00+00:00',
#                'season': {'end_date': '2019-05-13',
#                           'id': 'sr:season:54571',
#                           'name': 'Premier League 18/19',
#                           'start_date': '2018-08-10',
#                           'tournament_id': 'sr:tournament:17',
#                           'year': '18/19'},
#                'start_time_tbd': False,
#                'status': 'not_started',
#                'tournament': {'category': {'country_code': 'ENG',
#                                            'id': 'sr:category:1',
#                                            'name': 'England'},
#                               'id': 'sr:tournament:17',
#                               'name': 'Premier League',
#                               'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#                'tournament_round': {'number': 36,
#                                     'phase': 'regular season',
#                                     'type': 'group'},
#                'venue': {'capacity': 21401,
#                          'city_name': 'Burnley',
#                          'country_code': 'ENG',
#                          'country_name': 'England',
#                          'id': 'sr:venue:806',
#                          'map_coordinates': '53.789167,-2.230278',
#                          'name': 'Turf Moor'}},
#               {'competitors': [{'abbreviation': 'MCI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:17',
#                                 'name': 'Manchester City',
#                                 'qualifier': 'home'},
#                                {'abbreviation': 'LEI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:31',
#                                 'name': 'Leicester City',
#                                 'qualifier': 'away'}],
#                'id': 'sr:match:14736961',
#                'scheduled': '2019-05-06T19:00:00+00:00',
#                'season': {'end_date': '2019-05-13',
#                           'id': 'sr:season:54571',
#                           'name': 'Premier League 18/19',
#                           'start_date': '2018-08-10',
#                           'tournament_id': 'sr:tournament:17',
#                           'year': '18/19'},
#                'start_time_tbd': False,
#                'status': 'not_started',
#                'tournament': {'category': {'country_code': 'ENG',
#                                            'id': 'sr:category:1',
#                                            'name': 'England'},
#                               'id': 'sr:tournament:17',
#                               'name': 'Premier League',
#                               'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#                'tournament_round': {'number': 37,
#                                     'phase': 'regular season',
#                                     'type': 'group'},
#                'venue': {'capacity': 46708,
#                          'city_name': 'Manchester',
#                          'country_code': 'ENG',
#                          'country_name': 'England',
#                          'id': 'sr:venue:606',
#                          'map_coordinates': '53.484592,-2.202695',
#                          'name': 'Etihad Stadium'}},
#               {'competitors': [{'abbreviation': 'BHA',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:30',
#                                 'name': 'Brighton & Hove Albion FC',
#                                 'qualifier': 'home'},
#                                {'abbreviation': 'MCI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:17',
#                                 'name': 'Manchester City',
#                                 'qualifier': 'away'}],
#                'id': 'sr:match:14736997',
#                'scheduled': '2019-05-12T14:00:00+00:00',
#                'season': {'end_date': '2019-05-13',
#                           'id': 'sr:season:54571',
#                           'name': 'Premier League 18/19',
#                           'start_date': '2018-08-10',
#                           'tournament_id': 'sr:tournament:17',
#                           'year': '18/19'},
#                'start_time_tbd': False,
#                'status': 'not_started',
#                'tournament': {'category': {'country_code': 'ENG',
#                                            'id': 'sr:category:1',
#                                            'name': 'England'},
#                               'id': 'sr:tournament:17',
#                               'name': 'Premier League',
#                               'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#                'tournament_round': {'number': 38,
#                                     'phase': 'regular season',
#                                     'type': 'group'},
#                'venue': {'capacity': 30750,
#                          'city_name': 'Falmer',
#                          'country_code': 'ENG',
#                          'country_name': 'England',
#                          'id': 'sr:venue:2443',
#                          'map_coordinates': '50.861822,-0.083278',
#                          'name': 'American Express Community Stadium'}},
#               {'competitors': [{'abbreviation': 'MCI',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:17',
#                                 'name': 'Manchester City',
#                                 'qualifier': 'home'},
#                                {'abbreviation': 'WAT',
#                                 'country': 'England',
#                                 'country_code': 'ENG',
#                                 'id': 'sr:competitor:24',
#                                 'name': 'Watford FC',
#                                 'qualifier': 'away'}],
#                'id': 'sr:match:17901274',
#                'scheduled': '2019-05-18T16:00:00+00:00',
#                'season': {'end_date': '2019-05-19',
#                           'id': 'sr:season:55977',
#                           'name': 'FA Cup 18/19',
#                           'start_date': '2018-11-09',
#                           'tournament_id': 'sr:tournament:19',
#                           'year': '18/19'},
#                'start_time_tbd': False,
#                'status': 'not_started',
#                'tournament': {'category': {'country_code': 'ENG',
#                                            'id': 'sr:category:1',
#                                            'name': 'England'},
#                               'id': 'sr:tournament:19',
#                               'name': 'FA Cup',
#                               'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#                'tournament_round': {'cup_round_match_number': 1,
#                                     'cup_round_matches': 1,
#                                     'name': 'final',
#                                     'phase': 'knockout_stage',
#                                     'type': 'cup'},
#                'venue': {'capacity': 90000,
#                          'city_name': 'London',
#                          'country_code': 'ENG',
#                          'country_name': 'England',
#                          'id': 'sr:venue:8',
#                          'map_coordinates': '51.555833,-0.279722',
#                          'name': 'Wembley Stadium'}}],
#  'schema': 'http://schemas.sportradar.com/bsa/soccer/v1/json/endpoints/soccer/team_schedule.json',
#  'team': {'abbreviation': 'MCI',
#           'country': 'England',
#           'country_code': 'ENG',
#           'id': 'sr:competitor:17',
#           'name': 'Manchester City'}}

# %% [markdown]
# Inspecting the results, we can see that the schedule can be found under the "schedule" key to the top-level dictionary. It is a list of matches, with each match encoded in a dictionary.

# %%
schedule = result["schedule"]
print(type(schedule))
print(len(schedule))
# Out:
# <class 'list'>
# 5

# %% [markdown]
# Each match looks like this:

# %%
pprint(schedule[0])
# Out:
# {'competitors': [{'abbreviation': 'MUN',
#                   'country': 'England',
#                   'country_code': 'ENG',
#                   'id': 'sr:competitor:35',
#                   'name': 'Manchester United',
#                   'qualifier': 'home'},
#                  {'abbreviation': 'MCI',
#                   'country': 'England',
#                   'country_code': 'ENG',
#                   'id': 'sr:competitor:17',
#                   'name': 'Manchester City',
#                   'qualifier': 'away'}],
#  'id': 'sr:match:17487549',
#  'scheduled': '2019-04-24T19:00:00+00:00',
#  'season': {'end_date': '2019-05-13',
#             'id': 'sr:season:54571',
#             'name': 'Premier League 18/19',
#             'start_date': '2018-08-10',
#             'tournament_id': 'sr:tournament:17',
#             'year': '18/19'},
#  'start_time_tbd': False,
#  'status': 'not_started',
#  'tournament': {'category': {'country_code': 'ENG',
#                              'id': 'sr:category:1',
#                              'name': 'England'},
#                 'id': 'sr:tournament:17',
#                 'name': 'Premier League',
#                 'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}},
#  'tournament_round': {'number': 31, 'phase': 'regular season', 'type': 'group'},
#  'venue': {'capacity': 75635,
#            'city_name': 'Manchester',
#            'country_code': 'ENG',
#            'country_name': 'England',
#            'id': 'sr:venue:9',
#            'map_coordinates': '53.463150,-2.291444',
#            'name': 'Old Trafford'}}

# %% [markdown]
# #### 3.2.1.1 Exercise: accessing a soccer schedule
#
# Make a request to the Sportradar Soccer schedule API to obtain the match schedule for Liverpool FC (team_id = sr:competitor:44). Then, from the obtained schedule, make a simple list of fixtures. Your output should be a list with strings as elements. The strings should be of the format "HOME_TEAM vs AWAY_TEAM".

# %%
# code goes here

# %% [markdown]
# ### 3.3 Big Tech APIs
#
# Large tech companies make a variety of APIs available for use. Most of these require authentication and can be used to access some very useful data.
#
# #### 3.3.1 Facebook
#
# Facebook has an API called the Graph API that allows a developer to access data about posts, comments, users and more. However, one of the major sticking points of working with APIs from companies like Facebook is that these APIs change very frequently, and sometimes the changes can break a developer's code. Facebook changed their policy towards applications some time ago, and as a result, a developer simply working on a research project is not allowed access to any data from the Graph API. In order to gain data access, all developers must register their application and go through a review process with Facebook. Only then is data collection allowed through the API. These barriers make it hard to discuss and work with the Graph API.
#
# #### 3.3.2 Google
#
# Similarly, Google Maps has a very powerful API that can be used to obtain a large variety of data, however, it is meant to be used as a licensed resource for which developers pay Google a fee. Some of Google's tools may be used for free by obtaining a \$200 API credit, however, this still requires setting up billing. If you are interested in these tools, take a look [here](https://cloud.google.com/maps-platform/pricing/).
#
# An important consideration when working with these APIs is that companies usually enforce a "rate limit". This means a developer is only allowed to make calls under a certain frequency. When you are working with an API from a commercial entity, make sure to check on their rate limit.
#
# #### 3.3.3 Twitter
#
# A big-tech API we can demonstrate and play around with is the Twitter API. While the API can be accessed in a barebones way usings tools such as the `requests` module, we can also use an API client, which is a third-party library that allows us to easily work with an API by automating and simplifying low-level tasks.
#
# For Twitter, we'll use a client called Twython (`pip3 install Twython` to install). First, we'll need to follow these steps to obtain API access and authentication:
#
# 1. Sign up for a Twitter account
# 2. Sign in to [https://apps.twitter.com]
# 3. Create an app
# 4. Go to the API Keys section and click "Generate ACCESS TOKEN".
#
# The resulting keys are:
# - "oauth_access_token"
# - "oauth_access_token_secret"
# - "consumer_key"
# - "consumer_secret"
#
# We'll have to save these values in some variables that we'll need:

# %%
access_token = ''
access_token_secret = ''
consumer_key = ''
consumer_secret = ''

# %% [markdown]
# Now, we'll create a `twitter` object using our consumer key and secret and use this object to download a [list of tweets](https://www.buzzfeed.com/danieldalton/epic-tweet-bro?utm_term=.shgZJEe8V#.lywBJEpjG) using their unique IDs.

# %%
from twython import Twython

twitter = Twython(consumer_key, consumer_secret)

IDlist = [
    "1121915133", 
    "64780730286358528", 
    "64877790624886784", 
    "20", 
    "467192528878329856", 
    "474971393852182528",
    "475071400466972672",
    "475121451511844864",
    "440322224407314432",
    "266031293945503744",
    "3109544383",
    "1895942068",
    "839088619",
    "8062317551",
    "232348380431544320",
    "286910551899127808",
    "286948264236945408",
    "27418932143",
    "786571964",
    "467896522714017792",
    "290892494152028160",
    "470571408896962560"
]

for ID in IDlist:
    status = twitter.show_status(id = ID)
    print(status["text"])
# Out:
# http://twitpic.com/135xa - There's a plane in the Hudson. I'm on the ferry going to pick up the people. Crazy.
# Helicopter hovering above Abbottabad at 1AM (is a rare event).
# So I'm told by a reputable person they have killed Osama Bin Laden. Hot damn.
# just setting up my twttr
# India has won! भारत की विजय। अच्छे दिन आने वाले हैं।
# We can neither confirm nor deny that this is our first tweet.
# Thank you for the @Twitter welcome! We look forward to sharing great #unclassified content with you.
# @CIA We look forward to sharing great classified info about you http://t.co/QcdVxJfU4X https://t.co/kcEwpcitHo More: https://t.co/PEeUpPAt7F
# If only Bradley's arm was longer. Best photo ever. #oscars http://t.co/C9U5NOtGap
# Four more years. http://t.co/bAJE6Vom
# Facebook turned me down. It was a great opportunity to connect with some fantastic people. Looking forward to life's next adventure.
# Got denied by Twitter HQ. That's ok. Would have been a long commute.
# Are you ready to celebrate?  Well, get ready: We have ICE!!!!! Yes, ICE, *WATER ICE* on Mars!  w00t!!!  Best day ever!!
# Hello Twitterverse! We r now LIVE tweeting from the International Space Station -- the 1st live tweet from Space! :) More soon, send your ?s
# I'm safely on the surface of Mars. GALE CRATER I AM IN YOU!!! #MSL
# @Cmdr_Hadfield Are you tweeting from space? MBB
# @WilliamShatner Yes, Standard Orbit, Captain. And we're detecting signs of life on the surface.
# Everest summit! -Sent with @DeLormeGPS Earthmate PN-60w
# Arrested
# Just another night of playing Cards Against Humanity... http://t.co/lfu3YtdHRC
# Ugh - NEVER going to a Ryan Gosling movie in a theater again. Apparently masturbating in the back row is still considered "inappropriate"
# I don't know why I wasn't invited, I'm great at weddings... @KimKardashian @kanyewest

# %% [markdown]
# Next, we'll grab a user's timeline (Drexel University in this case) and print out the last 10 tweets by them:

# %%
drexel_twitter = twitter.get_user_timeline(screen_name = "drexeluniv")

for tweet in drexel_twitter[:10]:
    print(tweet["text"])
    print()
# Out:
# Congratulations to Johnny Zhu, who won first place in the “@ Play” category with his photo “Standing on the Shoulde… https://t.co/19TpUmJGZy
#
# Congratulations to Michelle Kim, who won first place in the “@ Work” category with her photo “Go Metro to the LA Op… https://t.co/k2r0VZtu2V
#
# Thank you to all who participated in the @Steinbright Co-op Photo Contest and sharing your incredible #Drexel co-op… https://t.co/rAkzaAzr6d
#
# Happy Tuesday! Don't forget to swing by EarthFest today between 11:30 a.m. and 1:30 p.m. on Lancaster Walk! 🌎 https://t.co/6oFjgkqdM7
#
# RT @DrexelNow: It's #EarthDay today. Here's how @DrexelUniv is dedicated to transforming its campus into a sustainability leader: https://t…
#
# It’s World Dragon Week at Drexel! 🌎🐉 Join us in celebrating the cultural diversity represented on our campus with e… https://t.co/ImXKWwcmGG
#
# Happy #EarthDay Dragons! Each year, Drexel celebrates its commitment to environmental sustainability with our annua… https://t.co/zMsRNmzIzc
#
# Don't forget to tune into ABC tonight at 10 p.m. EST to see former Drexel lacrosse player Kyle Bergman in the Shark… https://t.co/O4mFyKDnGC
#
# RT @DrexelAdmission: No matter who you are or where you're from, all of us at Drexel are excited to welcome you as one of our own. Hear fro…
#
# This weekend, Drexel graduate Kyle Bergman and his company @swoveralls will be featured on @ABCSharkTank! Watch the… https://t.co/vpx8Ku4jb1

# %% [markdown]
# #### 3.3.3.1 Exercise: access some accidental haikus from Twitter's REST API
# Create your Twitter API keys and download the last 15 tweets by @accidental575 (the hilarious Accidental Haiku Bot).

# %%
# code goes here

# %% [markdown]
# #### 3.3.3.2 Complex queries with filtering
# We can use Twitter's Search API to grab some tweets about a particular topic:

# %%
results = twitter.search(q = '"data science"')
for tweet in results["statuses"]:
    print(tweet["text"])
    print()
# Out:
# https://t.co/br4slRoeTj https://t.co/NSZNAhE9zP
#
# RT @DD_Serena_: Visual Data Storytelling with Tableau (Addison-Wesley Data &amp; Analytics Series) https://t.co/dfjkWwVP8k #Tableau
#
# RT @DD_FaFa_: Visual Data Storytelling with Tableau (Addison-Wesley Data &amp; Analytics Series) https://t.co/w6gvd9Zu5f #Tableau
#
# RT @dataquestio: Dive into our new Data Analyst in R #rstats path:
#
# - Interactive coding in your browser
# - No videos to sit through
# - No pr…
#
# RT @KirkDBorne: New #DataScience 10-page (PDF) Cheat Sheet covers basic concepts in probability, #statistics, statistical learning, #Machin…
#
# RT @DataRubix: Such valid insights by @schmarzo !! The role of critical thinking in #DataScience https://t.co/2YosCuhSZy #DataDriven #DataA…
#
# An interesting list of #DataScience and #ML resources
# https://t.co/YMbiC7CUER
#
# RT @schmarzo: 3 #DesignCanvases that link your business model to #DataScience and #ML initiatives and give #DataScientists direct line of s…
#
# Enterprise Products is hiring in #Houston, TX! Read about our latest #IT job opening via the link in our bio: Specialist, Lead Data Science
#
# RT @wasabi_cloud: According to new research, “#ArtificialIntelligence algorithms coupled with top data science can hunt cancer faster than…
#
# According to new research, “#ArtificialIntelligence algorithms coupled with top data science can hunt cancer faster… https://t.co/9k7TPtopMp
#
# @schmarzo on #CriticalThinking https://t.co/X2gf7BBMGg
#
# RT @Ronald_vanLoon: The Future of #DataScience in One Picture
#  by @granvilledsc @DataScienceCtrl @AnalyticBridge @BoozAllen |
#
# Read more he…
#
# RT @DataScienceFest: Data Science Festival 2019 Video with @TomEwing1979, Senior Data Scientist at Mango Solutions @MangoTheCat
# "6 Things…
#
# RT @spdustin: Holy hell, I'm a glutton for punishment. I've decided to do a whole series of articles on using data science and #NLP to extr…

# %% [markdown]
# #### 3.3.3.3 Twitter's streaming APIs
# he Streaming API lets us collect a portion of all the tweets currently being posted, in real time. This is more complicated than collecting old tweets, because it means essentially downloading an endless stream of data. Let's say we want to collect 30 tweets and stop. We need to write a class based on `TwythonStreamer` that has this failsafe built-in, while also only collecting English tweets:

# %%
from twython import TwythonStreamer

tweets = []

class Streamer(TwythonStreamer):
    
    def on_success(self, data):
        
        if data["lang"] == "en":
            tweets.append(data)
            print("Received tweet #" + str(len(tweets)))
            
        if len(tweets) >= 30:
            self.disconnect()
            
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

# %% [markdown]
# Next, we need to `Streamer` object and use it to collect tweets. Let's say we want to collect tweets with the keyword "science":

# %%
stream = Streamer(consumer_key, consumer_secret, access_token, access_token_secret)

stream.statuses.filter(track = "science")
# Out:
# Received tweet #1
# Received tweet #2
# Received tweet #3
# Received tweet #4
# Received tweet #5
# Received tweet #6
# Received tweet #7
# Received tweet #8
# Received tweet #9
# Received tweet #10
# Received tweet #11
# Received tweet #12
# Received tweet #13
# Received tweet #14
# Received tweet #15
# Received tweet #16
# Received tweet #17
# Received tweet #18
# Received tweet #19
# Received tweet #20
# Received tweet #21
# Received tweet #22
# Received tweet #23
# Received tweet #24
# Received tweet #25
# Received tweet #26
# Received tweet #27
# Received tweet #28
# Received tweet #29
# Received tweet #30

# %% [markdown]
# Let's take a look at these 30 tweets, collected in real time:

# %%
for tweet in tweets:
    print(tweet["text"])
    print()
# Out:
# All Science: Kuwaiti TV Promotes Homosexuality "Cure" With Suppository That Kills Semen-Eating Anal Worms -… https://t.co/W11KOP8l88
#
# @BobStein_FT This program isn't just for teachers, it is also military and federal employees as an incentive to sta… https://t.co/YI9h7z49cu
#
# Hello @Space_Station from Morrison High School Science Class 285.2 mi away @NASA_Johnson #issabove https://t.co/WMp8SwaoS4
#
# RT @baaaadscience: 90% of what you consist of is undetectable by science.
#
# I've entered to #win two Beaker Creature Reactor Pods from @LRUK with @anywaytostay #competition #win #comp #toys… https://t.co/ISohhwJGnS
#
# LabAnimal: A Nature Research journal covering in vivo science and technology using......
# model organisms of human… https://t.co/nSTEoGy9R5
#
# RT @arstechnica: Listen up: We’ve detected our first marsquake https://t.co/2TocxFQYNU by @SciGuySpace
#
# I redid an ENTIRE science project on my own in elementary bc I hated how my partner and I did it. 💀😂
#
# RT @msalli_: literally in year 9, I would just walk in and my science teacher would just say ‘out’ LOOOOL I hadn’t even done nothing🤣🤣 http…
#
# RT @OliviaLittle: Do you understand how hard it is for me not to cyberbully my political science professor who spends the class monologuing…
#
# RT @AskStacyYoung: #nctevillage looking for science fiction short story and novel suggestions appropriate for YA, featuring characters of c…
#
# “It’s basically science”
#
# RT @JuiceTooWavie: You would not believe Bill Nye
#
# If ten million Science Guys
#
# RT @MickyBell: #EarthDay - This is not science fiction. This is not a film. There is no planet B, we’re not going to colonise the Moon or M…
#
# SIGN    SHARE    --   PM Justin Trudeau; Minister of Science Kirsty Duncan; Health Minister Ginette Petitpas Taylor… https://t.co/0jNyWX7tov
#
# The 8th book on my #2019readingchallenge was "a book about science" and I picked Astrophysics for People in a Hurry… https://t.co/H7J4v6lzar
#
# RT @JuiceTooWavie: You would not believe Bill Nye
#
# If ten million Science Guys
#
# “You don’t listen to the science because you are only interested in solutions that will enable you to carry on like… https://t.co/77P1SmcIJF
#
# RT @SirHenryKau: This 7 month kid draws better than most of us even science can't explain this 😱😱😍 https://t.co/45Blcfy6ui
#
# @AnarchoBoogaloo Historically, stuff like alchemy was just science.
#
# RT @CR_UK: How do tumours ‘know’ where to spread? Read our Science Surgery post for the answer: https://t.co/CqVB1vt6jZ https://t.co/R1divW…
#
# RT @whsource: "in countries such as India, Italy, and the United States, negative attitudes about science appear to have risen in lockstep…
#
# RT @PhiweMkhuzo: PornHub titles are so unnecessarily... "Hot black girl with Degree In Science get Dicked Down by an unemployed man" https:…
#
# RT @oakley_red: Can food allergies be passed on through organ donation?
# It appears there is medical evidence to suggest so. See the case of…
#
# RT @TVMohandasPai: Fear mongering by discredited lying historians, usual behavior, being denied their role of power brokering. Indian acade…
#
# RT @weehalfpintt: Im loving watching grown men shit their frillies over a teen girl talking about science. Its fucking epic.
#
# So... one day the aliens will find Earth and wonder how in the universe anyone survived on a plastic planet? https://t.co/QP8n8TCLQA
#
# These TED Talks are perfect for kiddos excited about science and technology: https://t.co/ARVhqfEBG1
#
# RT @TheLabArtist: First lot of science-themed Pusheen illustrations (astronomer, chemist, geologist and meteorologist)! Going to be making…
#
# InSight has officially detected the first Marsquakes ever! More info here: https://t.co/5m7MoxR6oQ.
#
# Congrats to my… https://t.co/Be1Mm0LYoC

# %% [markdown]
# The Streaming API is a very powerful data source, but it can also generate quite a bit of data in a short period of time. So, whenever you're collecting tweets from the stream, make sure to design the collection in such a way that you don't run out of storage!
